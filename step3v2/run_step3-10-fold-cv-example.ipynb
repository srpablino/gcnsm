# %% [markdown]
# # 10-fold Cross validation example

# %%
"""
Choose the dataset name for the ground_truth and graph embeddings
"""
dataset_name = "openML"

"""
choose integer number of ratio negative/positive for the negative sampling (0 to 20)
"""
neg_sample = 2

"""
Choose experiment ["hold_out","random_subsam","10_cv"] : 
- hold_out will get the train/test split within ./ground_truth/dataset_name/hold_out
- random_subsam will isolate 1 node from some clusters of similar nodes in the ground truth. The isolated nodes will not be seen during training
- 10_cv: will split the ground truth in 10 folds, using each fold as test at least once. 
"""
strategy = "10_cv"

"""
Choose to use the selected strategy to create a new split 
or reuse a previously created one (useful to repeat exact same experiment)
"""
create_new_split = False

print("Env variables set")

#import libraries
import step3_gcnsm
from step3_gcnsm import confusion_matrix as confusion_matrix
from step3_gcnsm import train as train
from step3_gcnsm import cross_validation as cross_validation
from step3_gcnsm import test_mask, train_mask
from step3_gcnsm import g
import step3_gcn_nn_concatenate as gcn_nn
import step3_gcn_loss as gcn_loss
import step3_gcn_training as gcn_training
import step3_plot_results as plot
step3_gcnsm.load_env(ds_name=dataset_name,ns=neg_sample,experiment=strategy,new_split=create_new_split)
print("\n SETUP IS READY")
# Out:
# Env variables set
# Using backend: pytorch
# Values to load
# dataset_name=openML
# neg_sample= 2
# strategy= 10_cv
# create_new_split= True
# cross_v= 0
# Creating cross validation splits...
# /home/pablo/gcnsm/step3v2/step3_train_test_split.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   cv_pos = np.array(np.array_split(df_matching,10))
# /home/pablo/gcnsm/step3v2/step3_train_test_split.py:84: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   cv_neg = np.array(np.array_split(df_not_matching,10))
# CV Train/Test split done
# Dataset splits loaded
# Train positive samples: 488 Test positive samples: 55
# Meta-feature graph from datasets loaded
#
#  SETUP IS READY

# %% [markdown]
# # Choose NN architecture and loss function, then run tests

# %% [markdown]
# ### Config and run training
# ### NN architectures:

# %%
##run this to see the different options of NN architectures
gcn_nn.get_options()
# Out:
# {0: 'Bert2_400',
#  1: 'Bert2_832',
#  2: 'Bert2_832_400_200_100',
#  3: 'Bert2_832_600_400_200',
#  4: 'Bert_300',
#  5: 'Bert_300_300_200',
#  6: 'Bert_768',
#  7: 'Fasttext2',
#  8: 'Fasttext2_150',
#  9: 'Fasttext2_200_200',
#  10: 'Fasttext2_200_200_100',
#  11: 'Fasttext2_200_200_200',
#  12: 'Fasttext2_200_200_200_100',
#  13: 'Fasttext2_200_200_200_100_relu',
#  14: 'Fasttext2_300_250_200_150',
#  15: 'Fasttext2_364',
#  16: 'Fasttext2_364_200_100',
#  17: 'Fasttext2_364_200_100_relu',
#  18: 'Fasttext2_364_300_200_100',
#  19: 'Fasttext2_364_300_200_100_relu',
#  20: 'Fasttext2_364_300_250_200',
#  21: 'Fasttext2_364_364_364',
#  22: 'Fasttext2_364_nn',
#  23: 'Fasttext2_3GCN_300_250_200_150',
#  24: 'Fasttext2_728',
#  25: 'Fasttext2_728364',
#  26: 'Fasttext2_728_364',
#  27: 'Fasttext2d_300_250_200_150',
#  28: 'Fasttext2d_364',
#  29: 'Fasttext2d_364_364_364',
#  30: 'Fasttext2d_728_364',
#  31: 'Fasttext3GCN_300',
#  32: 'FasttextSum_150',
#  33: 'FasttextSum_300_250_200_150',
#  34: 'FasttextSum_364',
#  35: 'FasttextSum_364_200_100',
#  36: 'FasttextSum_364_300_200_100',
#  37: 'FasttextSumd_150',
#  38: 'FasttextSumd_300_250_200_150',
#  39: 'Fasttext_150',
#  40: 'Fasttext_150_150_100',
#  41: 'Fasttext_200_200_200_100',
#  42: 'Fasttext_300',
#  43: 'Fasttext_300_200_100',
#  44: 'Fasttext_300_250_200_150',
#  45: 'Fasttext_300_300_300',
#  46: 'Fasttext_3GCN',
#  47: 'Fasttext_600_300',
#  48: 'Fasttext_simple_300_300'}

# %% [markdown]
# ### Loss functions:
# {<br>
#     "0": "ContrastiveLoss", <br>
#     "1": "CosineEmbeddingLoss", <br>
# }
#
# ### Optimizer
# {<br>
#     "adam" (default)<br>
#     "sgd"<br>
# }
#
#
# ### Loss functions parameters examples: format -> [margin]+[aggregation_function]
# {<br>
#     0.9+mean, <br>
#     0.7+mean, <br>
#     0.5+mean, <br>
#     0.3+mean, <br>
#     0.9+sum, <br>
#     0.7+sum, <br>
#     0.5+sum, <br>
#     0.3+sum, <br>
# }
#
# ### batch_splits examples:
# {<br>
#     1024, <br>
#     2048, <br>
# }
# ### learning rate examples (lr):
# {<br>
#     6e-3, <br>
#     1e-2, <br>
# }

# %% [markdown]
# ### 10-fold Cross Validation run example

# %%
#train new model and specify parameters
training_object = gcn_training.Training()
training_object.set_training(
            net_name= "Fasttext2_364",  #_of_option for NN architecture
            batch_splits=1024 ,#_of_sets(this will (give dataset / batch_splits) size of batch
            lr=1e-2 , #learning rate for training (e.g. 1e-3 )
            loss_name=gcn_loss.get_option_name(1), #_of_option for loss 
            loss_parameters="0.5+mean" ,#loss function parameters separated by '+' e.g. for cosine and contrastive "0.0+mean"
            optimizer_name="sgd" ) #adam or sgd, default adam

cross_validation(training_object,120,"1-10",nsample=2)
# Out:
# Values to load
# dataset_name=openML
# neg_sample= 0
# strategy= 10_cv
# create_new_split= False
# cross_v= 0
# Dataset splits loaded
# Train positive samples: 488 Test positive samples: 55
# Meta-feature graph from datasets loaded
# Start of training...NN Fasttext2_364 Loss CosineEmbeddingLoss Split 1024:
# Ep:0, loss:0.00061, loss_test:0.24363, lr:1.00e-02, fs:0.66667 (r=1.000,p=0.500),  time:6.217, tt:6.217
# ##########Best model found so far##########
# Ep:1, loss:0.00061, loss_test:0.24147, lr:9.90e-03, fs:0.66667 (r=1.000,p=0.500),  time:6.118, tt:12.236
# Ep:2, loss:0.00059, loss_test:0.23675, lr:9.80e-03, fs:0.66667 (r=1.000,p=0.500),  time:6.121, tt:18.363
# Ep:3, loss:0.00056, loss_test:0.22672, lr:9.70e-03, fs:0.66667 (r=1.000,p=0.500),  time:6.058, tt:24.231
# Ep:4, loss:0.00051, loss_test:0.20540, lr:9.61e-03, fs:0.65854 (r=0.982,p=0.495),  time:6.017, tt:30.084
# Ep:5, loss:0.00040, loss_test:0.19341, lr:9.51e-03, fs:0.69444 (r=0.909,p=0.562),  time:6.016, tt:36.094
# ##########Best model found so far##########
# Ep:6, loss:0.00033, loss_test:0.19285, lr:9.41e-03, fs:0.66154 (r=0.782,p=0.573),  time:5.951, tt:41.657
# Ep:7, loss:0.00031, loss_test:0.19129, lr:9.32e-03, fs:0.69355 (r=0.782,p=0.623),  time:5.929, tt:47.435
# Ep:8, loss:0.00029, loss_test:0.19106, lr:9.23e-03, fs:0.69355 (r=0.782,p=0.623),  time:5.916, tt:53.244
# Ep:9, loss:0.00029, loss_test:0.19580, lr:9.14e-03, fs:0.72881 (r=0.782,p=0.683),  time:5.869, tt:58.690
# ##########Best model found so far##########
# Ep:10, loss:0.00029, loss_test:0.19332, lr:9.04e-03, fs:0.71186 (r=0.764,p=0.667),  time:5.843, tt:64.271
# Ep:11, loss:0.00027, loss_test:0.18503, lr:8.95e-03, fs:0.75806 (r=0.855,p=0.681),  time:5.821, tt:69.855
# ##########Best model found so far##########
# Ep:12, loss:0.00026, loss_test:0.17794, lr:8.86e-03, fs:0.75410 (r=0.836,p=0.687),  time:5.813, tt:75.564
# Ep:13, loss:0.00025, loss_test:0.17081, lr:8.78e-03, fs:0.74194 (r=0.836,p=0.667),  time:5.840, tt:81.764
# Ep:14, loss:0.00025, loss_test:0.16718, lr:8.69e-03, fs:0.75410 (r=0.836,p=0.687),  time:5.832, tt:87.484
# Ep:15, loss:0.00024, loss_test:0.16371, lr:8.60e-03, fs:0.78333 (r=0.855,p=0.723),  time:5.827, tt:93.240
# ##########Best model found so far##########
# Ep:16, loss:0.00023, loss_test:0.15638, lr:8.51e-03, fs:0.75806 (r=0.855,p=0.681),  time:5.968, tt:101.458
# Ep:17, loss:0.00022, loss_test:0.15196, lr:8.43e-03, fs:0.77778 (r=0.891,p=0.690),  time:6.095, tt:109.718
# Ep:18, loss:0.00021, loss_test:0.14780, lr:8.35e-03, fs:0.78689 (r=0.873,p=0.716),  time:6.091, tt:115.734
# ##########Best model found so far##########
# Ep:19, loss:0.00020, loss_test:0.14041, lr:8.26e-03, fs:0.80000 (r=0.909,p=0.714),  time:6.108, tt:122.156
# ##########Best model found so far##########
# Ep:20, loss:0.00020, loss_test:0.14033, lr:8.18e-03, fs:0.79675 (r=0.891,p=0.721),  time:6.079, tt:127.663
# Ep:21, loss:0.00020, loss_test:0.13086, lr:8.10e-03, fs:0.83200 (r=0.945,p=0.743),  time:6.056, tt:133.233
# ##########Best model found so far##########
# Ep:22, loss:0.00019, loss_test:0.12977, lr:8.02e-03, fs:0.86667 (r=0.945,p=0.800),  time:6.030, tt:138.700
# ##########Best model found so far##########
# Ep:23, loss:0.00018, loss_test:0.12682, lr:7.94e-03, fs:0.84034 (r=0.909,p=0.781),  time:6.007, tt:144.180
# Ep:24, loss:0.00018, loss_test:0.12123, lr:7.86e-03, fs:0.84034 (r=0.909,p=0.781),  time:5.984, tt:149.588
# Ep:25, loss:0.00017, loss_test:0.11896, lr:7.78e-03, fs:0.85714 (r=0.927,p=0.797),  time:6.012, tt:156.305
# Ep:26, loss:0.00016, loss_test:0.11346, lr:7.70e-03, fs:0.85714 (r=0.927,p=0.797),  time:6.000, tt:161.993
# Ep:27, loss:0.00016, loss_test:0.10832, lr:7.62e-03, fs:0.85246 (r=0.945,p=0.776),  time:5.976, tt:167.329
# Ep:28, loss:0.00015, loss_test:0.10996, lr:7.55e-03, fs:0.88136 (r=0.945,p=0.825),  time:5.973, tt:173.205
# ##########Best model found so far##########
# Ep:29, loss:0.00016, loss_test:0.10578, lr:7.47e-03, fs:0.89831 (r=0.964,p=0.841),  time:5.966, tt:178.986
# ##########Best model found so far##########
# Ep:30, loss:0.00014, loss_test:0.10173, lr:7.40e-03, fs:0.88889 (r=0.945,p=0.839),  time:5.955, tt:184.602
# Ep:31, loss:0.00014, loss_test:0.09584, lr:7.32e-03, fs:0.87603 (r=0.964,p=0.803),  time:5.976, tt:191.244
# Ep:32, loss:0.00014, loss_test:0.10303, lr:7.25e-03, fs:0.86726 (r=0.891,p=0.845),  time:5.983, tt:197.452
# Ep:33, loss:0.00013, loss_test:0.09203, lr:7.18e-03, fs:0.89256 (r=0.982,p=0.818),  time:5.981, tt:203.345
# Ep:34, loss:0.00013, loss_test:0.09179, lr:7.11e-03, fs:0.88333 (r=0.964,p=0.815),  time:5.980, tt:209.309
# Ep:35, loss:0.00012, loss_test:0.09038, lr:7.03e-03, fs:0.87603 (r=0.964,p=0.803),  time:5.982, tt:215.341
# Ep:36, loss:0.00012, loss_test:0.08586, lr:6.96e-03, fs:0.89256 (r=0.982,p=0.818),  time:5.982, tt:221.320
# Ep:37, loss:0.00011, loss_test:0.08689, lr:6.89e-03, fs:0.90598 (r=0.964,p=0.855),  time:6.040, tt:229.530
# ##########Best model found so far##########
# Ep:38, loss:0.00011, loss_test:0.08264, lr:6.83e-03, fs:0.90756 (r=0.982,p=0.844),  time:6.117, tt:238.557
# ##########Best model found so far##########
# Ep:39, loss:0.00011, loss_test:0.07989, lr:6.76e-03, fs:0.92174 (r=0.964,p=0.883),  time:6.172, tt:246.887
# ##########Best model found so far##########
# Ep:40, loss:0.00011, loss_test:0.07605, lr:6.69e-03, fs:0.92308 (r=0.982,p=0.871),  time:6.160, tt:252.580
# ##########Best model found so far##########
# Ep:41, loss:0.00010, loss_test:0.08240, lr:6.62e-03, fs:0.93694 (r=0.945,p=0.929),  time:6.148, tt:258.228
# ##########Best model found so far##########
# Ep:42, loss:0.00010, loss_test:0.07964, lr:6.56e-03, fs:0.90435 (r=0.945,p=0.867),  time:6.137, tt:263.890
# Ep:43, loss:0.00010, loss_test:0.07122, lr:6.49e-03, fs:0.89256 (r=0.982,p=0.818),  time:6.121, tt:269.332
# Ep:44, loss:0.00009, loss_test:0.08596, lr:6.43e-03, fs:0.89091 (r=0.891,p=0.891),  time:6.127, tt:275.728
# Ep:45, loss:0.00009, loss_test:0.07568, lr:6.36e-03, fs:0.92174 (r=0.964,p=0.883),  time:6.117, tt:281.379
# Ep:46, loss:0.00009, loss_test:0.07673, lr:6.30e-03, fs:0.91892 (r=0.927,p=0.911),  time:6.106, tt:286.978
# Ep:47, loss:0.00009, loss_test:0.06839, lr:6.24e-03, fs:0.91379 (r=0.964,p=0.869),  time:6.106, tt:293.082
# Ep:48, loss:0.00007, loss_test:0.06824, lr:6.17e-03, fs:0.92174 (r=0.964,p=0.883),  time:6.108, tt:299.307
# Ep:49, loss:0.00008, loss_test:0.06541, lr:6.11e-03, fs:0.92982 (r=0.964,p=0.898),  time:6.104, tt:305.214
# Ep:50, loss:0.00008, loss_test:0.07476, lr:6.05e-03, fs:0.91892 (r=0.927,p=0.911),  time:6.108, tt:311.525
# Ep:51, loss:0.00007, loss_test:0.06751, lr:5.99e-03, fs:0.92857 (r=0.945,p=0.912),  time:6.108, tt:317.636
# Ep:52, loss:0.00007, loss_test:0.06325, lr:5.93e-03, fs:0.92982 (r=0.964,p=0.898),  time:6.114, tt:324.016
# Ep:53, loss:0.00007, loss_test:0.06553, lr:5.87e-03, fs:0.92174 (r=0.964,p=0.883),  time:6.115, tt:330.192
# Ep:54, loss:0.00007, loss_test:0.06339, lr:5.81e-03, fs:0.93694 (r=0.945,p=0.929),  time:6.122, tt:336.724
# Ep:55, loss:0.00007, loss_test:0.06196, lr:5.75e-03, fs:0.93694 (r=0.945,p=0.929),  time:6.118, tt:342.591
# Ep:56, loss:0.00006, loss_test:0.06184, lr:5.70e-03, fs:0.92982 (r=0.964,p=0.898),  time:6.108, tt:348.144
# Ep:57, loss:0.00006, loss_test:0.05834, lr:5.64e-03, fs:0.91379 (r=0.964,p=0.869),  time:6.115, tt:354.696
# Ep:58, loss:0.00006, loss_test:0.06127, lr:5.58e-03, fs:0.93694 (r=0.945,p=0.929),  time:6.144, tt:362.470
# Ep:59, loss:0.00006, loss_test:0.06188, lr:5.53e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.196, tt:371.730
# ##########Best model found so far##########
# Ep:60, loss:0.00005, loss_test:0.05233, lr:5.47e-03, fs:0.93805 (r=0.964,p=0.914),  time:6.242, tt:380.734
# Ep:61, loss:0.00006, loss_test:0.05333, lr:5.42e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.241, tt:386.930
# Ep:62, loss:0.00005, loss_test:0.05336, lr:5.36e-03, fs:0.92857 (r=0.945,p=0.912),  time:6.242, tt:393.261
# Ep:63, loss:0.00005, loss_test:0.05243, lr:5.31e-03, fs:0.93805 (r=0.964,p=0.914),  time:6.244, tt:399.634
# Ep:64, loss:0.00005, loss_test:0.05563, lr:5.26e-03, fs:0.93805 (r=0.964,p=0.914),  time:6.241, tt:405.655
# Ep:65, loss:0.00004, loss_test:0.05096, lr:5.20e-03, fs:0.93694 (r=0.945,p=0.929),  time:6.240, tt:411.862
# Ep:66, loss:0.00004, loss_test:0.04979, lr:5.15e-03, fs:0.93694 (r=0.945,p=0.929),  time:6.233, tt:417.598
# Ep:67, loss:0.00004, loss_test:0.05064, lr:5.10e-03, fs:0.93694 (r=0.945,p=0.929),  time:6.230, tt:423.651
# Ep:68, loss:0.00004, loss_test:0.05292, lr:5.05e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.222, tt:429.325
# Ep:69, loss:0.00004, loss_test:0.04959, lr:5.00e-03, fs:0.95495 (r=0.964,p=0.946),  time:6.219, tt:435.340
# ##########Best model found so far##########
# Ep:70, loss:0.00004, loss_test:0.04832, lr:4.95e-03, fs:0.93694 (r=0.945,p=0.929),  time:6.217, tt:441.434
# Ep:71, loss:0.00004, loss_test:0.04982, lr:4.90e-03, fs:0.92857 (r=0.945,p=0.912),  time:6.210, tt:447.096
# Ep:72, loss:0.00004, loss_test:0.04754, lr:4.85e-03, fs:0.92857 (r=0.945,p=0.912),  time:6.209, tt:453.281
# Ep:73, loss:0.00004, loss_test:0.04661, lr:4.80e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.204, tt:459.124
# Ep:74, loss:0.00004, loss_test:0.04983, lr:4.75e-03, fs:0.93694 (r=0.945,p=0.929),  time:6.200, tt:464.982
# Ep:75, loss:0.00003, loss_test:0.04720, lr:4.71e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.196, tt:470.867
# Ep:76, loss:0.00003, loss_test:0.04626, lr:4.66e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.193, tt:476.844
# Ep:77, loss:0.00003, loss_test:0.05105, lr:4.61e-03, fs:0.93694 (r=0.945,p=0.929),  time:6.190, tt:482.794
# Ep:78, loss:0.00003, loss_test:0.04578, lr:4.57e-03, fs:0.94643 (r=0.964,p=0.930),  time:6.183, tt:488.434
# Ep:79, loss:0.00003, loss_test:0.04546, lr:4.52e-03, fs:0.93805 (r=0.964,p=0.914),  time:6.213, tt:497.009
# Ep:80, loss:0.00003, loss_test:0.05173, lr:4.48e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.247, tt:506.004
# Ep:81, loss:0.00003, loss_test:0.04844, lr:4.43e-03, fs:0.92857 (r=0.945,p=0.912),  time:6.288, tt:515.640
# Ep:82, loss:0.00003, loss_test:0.04881, lr:4.39e-03, fs:0.92727 (r=0.927,p=0.927),  time:6.285, tt:521.620
# Ep:83, loss:0.00003, loss_test:0.04570, lr:4.34e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.277, tt:527.306
# Ep:84, loss:0.00003, loss_test:0.04930, lr:4.30e-03, fs:0.93578 (r=0.927,p=0.944),  time:6.273, tt:533.236
# Ep:85, loss:0.00003, loss_test:0.04600, lr:4.26e-03, fs:0.93694 (r=0.945,p=0.929),  time:6.271, tt:539.286
# Ep:86, loss:0.00002, loss_test:0.04416, lr:4.21e-03, fs:0.93694 (r=0.945,p=0.929),  time:6.264, tt:544.974
# Ep:87, loss:0.00002, loss_test:0.04534, lr:4.17e-03, fs:0.93694 (r=0.945,p=0.929),  time:6.261, tt:550.944
# Ep:88, loss:0.00002, loss_test:0.04256, lr:4.13e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.257, tt:556.875
# Ep:89, loss:0.00002, loss_test:0.04271, lr:4.09e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.252, tt:562.722
# Ep:90, loss:0.00002, loss_test:0.04578, lr:4.05e-03, fs:0.92727 (r=0.927,p=0.927),  time:6.248, tt:568.613
# Ep:91, loss:0.00002, loss_test:0.04206, lr:4.01e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.245, tt:574.551
# Ep:92, loss:0.00002, loss_test:0.04632, lr:3.97e-03, fs:0.92727 (r=0.927,p=0.927),  time:6.241, tt:580.438
# Ep:93, loss:0.00002, loss_test:0.04194, lr:3.93e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.237, tt:586.287
# Ep:94, loss:0.00002, loss_test:0.03996, lr:3.89e-03, fs:0.95495 (r=0.964,p=0.946),  time:6.234, tt:592.262
# Ep:95, loss:0.00002, loss_test:0.04243, lr:3.85e-03, fs:0.92727 (r=0.927,p=0.927),  time:6.229, tt:597.970
# Ep:96, loss:0.00002, loss_test:0.04147, lr:3.81e-03, fs:0.93578 (r=0.927,p=0.944),  time:6.225, tt:603.810
# Ep:97, loss:0.00002, loss_test:0.03889, lr:3.77e-03, fs:0.95495 (r=0.964,p=0.946),  time:6.222, tt:609.709
# Ep:98, loss:0.00002, loss_test:0.04391, lr:3.73e-03, fs:0.93578 (r=0.927,p=0.944),  time:6.217, tt:615.519
# Ep:99, loss:0.00002, loss_test:0.03996, lr:3.70e-03, fs:0.93578 (r=0.927,p=0.944),  time:6.212, tt:621.171
# Ep:100, loss:0.00002, loss_test:0.03924, lr:3.66e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.208, tt:626.988
# Ep:101, loss:0.00002, loss_test:0.04078, lr:3.62e-03, fs:0.93578 (r=0.927,p=0.944),  time:6.233, tt:635.790
# Ep:102, loss:0.00001, loss_test:0.04090, lr:3.59e-03, fs:0.93578 (r=0.927,p=0.944),  time:6.252, tt:643.977
# Ep:103, loss:0.00001, loss_test:0.03834, lr:3.55e-03, fs:0.93578 (r=0.927,p=0.944),  time:6.253, tt:650.344
# Ep:104, loss:0.00002, loss_test:0.03787, lr:3.52e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.251, tt:656.307
# Ep:105, loss:0.00001, loss_test:0.03962, lr:3.48e-03, fs:0.93578 (r=0.927,p=0.944),  time:6.246, tt:662.049
# Ep:106, loss:0.00001, loss_test:0.03831, lr:3.45e-03, fs:0.93578 (r=0.927,p=0.944),  time:6.240, tt:667.655
# Ep:107, loss:0.00001, loss_test:0.03706, lr:3.41e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.237, tt:673.628
# Ep:108, loss:0.00001, loss_test:0.03761, lr:3.38e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.235, tt:679.586
# Ep:109, loss:0.00001, loss_test:0.03881, lr:3.34e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.231, tt:685.372
# Ep:110, loss:0.00001, loss_test:0.03744, lr:3.31e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.229, tt:691.425
# Ep:111, loss:0.00001, loss_test:0.03586, lr:3.28e-03, fs:0.95495 (r=0.964,p=0.946),  time:6.216, tt:696.237
# Ep:112, loss:0.00001, loss_test:0.03794, lr:3.24e-03, fs:0.93578 (r=0.927,p=0.944),  time:6.202, tt:700.803
# Ep:113, loss:0.00001, loss_test:0.03707, lr:3.21e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.187, tt:705.281
# Ep:114, loss:0.00001, loss_test:0.03619, lr:3.18e-03, fs:0.93578 (r=0.927,p=0.944),  time:6.171, tt:709.664
# Ep:115, loss:0.00001, loss_test:0.03652, lr:3.15e-03, fs:0.93578 (r=0.927,p=0.944),  time:6.176, tt:716.384
# Ep:116, loss:0.00001, loss_test:0.03646, lr:3.12e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.173, tt:722.247
# Ep:117, loss:0.00001, loss_test:0.03653, lr:3.09e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.168, tt:727.803
# Ep:118, loss:0.00001, loss_test:0.03529, lr:3.05e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.166, tt:733.786
# Ep:119, loss:0.00001, loss_test:0.03426, lr:3.02e-03, fs:0.94545 (r=0.945,p=0.945),  time:6.165, tt:739.776
# Model and results saved
# Saving best model...
# Model and results saved
# Values to load
# dataset_name=openML
# neg_sample= 0
# strategy= 10_cv
# create_new_split= False
# cross_v= 1
# Dataset splits loaded
# Train positive samples: 488 Test positive samples: 55
# Meta-feature graph from datasets loaded
# Start of training...NN Fasttext2_364 Loss CosineEmbeddingLoss Split 1024:
# Ep:0, loss:0.00061, loss_test:0.24437, lr:1.00e-02, fs:0.66667 (r=1.000,p=0.500),  time:9.045, tt:9.045
# ##########Best model found so far##########
# Ep:1, loss:0.00061, loss_test:0.24252, lr:9.90e-03, fs:0.66667 (r=1.000,p=0.500),  time:8.828, tt:17.655
# Ep:2, loss:0.00060, loss_test:0.23840, lr:9.80e-03, fs:0.66667 (r=1.000,p=0.500),  time:8.489, tt:25.466
# Ep:3, loss:0.00056, loss_test:0.22871, lr:9.70e-03, fs:0.66667 (r=1.000,p=0.500),  time:7.781, tt:31.123
# Ep:4, loss:0.00051, loss_test:0.20603, lr:9.61e-03, fs:0.65031 (r=0.964,p=0.491),  time:7.399, tt:36.994
# Ep:5, loss:0.00041, loss_test:0.17924, lr:9.51e-03, fs:0.71329 (r=0.927,p=0.580),  time:7.075, tt:42.452
# ##########Best model found so far##########
# Ep:6, loss:0.00033, loss_test:0.17721, lr:9.41e-03, fs:0.73684 (r=0.891,p=0.628),  time:6.796, tt:47.576
# ##########Best model found so far##########
# Ep:7, loss:0.00032, loss_test:0.17614, lr:9.32e-03, fs:0.71875 (r=0.836,p=0.630),  time:6.628, tt:53.020
# Ep:8, loss:0.00030, loss_test:0.17404, lr:9.23e-03, fs:0.75410 (r=0.836,p=0.687),  time:6.480, tt:58.324
# ##########Best model found so far##########
# Ep:9, loss:0.00029, loss_test:0.16631, lr:9.14e-03, fs:0.72000 (r=0.818,p=0.643),  time:6.372, tt:63.718
# Ep:10, loss:0.00029, loss_test:0.16304, lr:9.04e-03, fs:0.78992 (r=0.855,p=0.734),  time:6.297, tt:69.268
# ##########Best model found so far##########
# Ep:11, loss:0.00027, loss_test:0.15541, lr:8.95e-03, fs:0.76563 (r=0.891,p=0.671),  time:6.232, tt:74.780
# Ep:12, loss:0.00027, loss_test:0.15741, lr:8.86e-03, fs:0.80672 (r=0.873,p=0.750),  time:6.189, tt:80.461
# ##########Best model found so far##########
# Ep:13, loss:0.00025, loss_test:0.14745, lr:8.78e-03, fs:0.81890 (r=0.945,p=0.722),  time:6.149, tt:86.079
# ##########Best model found so far##########
# Ep:14, loss:0.00025, loss_test:0.14665, lr:8.69e-03, fs:0.84298 (r=0.927,p=0.773),  time:6.107, tt:91.606
# ##########Best model found so far##########
# Ep:15, loss:0.00024, loss_test:0.13820, lr:8.60e-03, fs:0.82258 (r=0.927,p=0.739),  time:6.073, tt:97.171
# Ep:16, loss:0.00024, loss_test:0.13953, lr:8.51e-03, fs:0.89655 (r=0.945,p=0.852),  time:6.058, tt:102.984
# ##########Best model found so far##########
# Ep:17, loss:0.00022, loss_test:0.12997, lr:8.43e-03, fs:0.85714 (r=0.927,p=0.797),  time:6.031, tt:108.565
# Ep:18, loss:0.00021, loss_test:0.12423, lr:8.35e-03, fs:0.86400 (r=0.982,p=0.771),  time:6.047, tt:114.886
# Ep:19, loss:0.00021, loss_test:0.12436, lr:8.26e-03, fs:0.87805 (r=0.982,p=0.794),  time:6.032, tt:120.638
# Ep:20, loss:0.00020, loss_test:0.12216, lr:8.18e-03, fs:0.85714 (r=0.982,p=0.761),  time:6.045, tt:126.938
# Ep:21, loss:0.00020, loss_test:0.11588, lr:8.10e-03, fs:0.85938 (r=1.000,p=0.753),  time:6.029, tt:132.640
# Ep:22, loss:0.00019, loss_test:0.11356, lr:8.02e-03, fs:0.88525 (r=0.982,p=0.806),  time:6.038, tt:138.878
# Ep:23, loss:0.00018, loss_test:0.10792, lr:7.94e-03, fs:0.87097 (r=0.982,p=0.783),  time:6.169, tt:148.056
# Ep:24, loss:0.00018, loss_test:0.10414, lr:7.86e-03, fs:0.90000 (r=0.982,p=0.831),  time:6.334, tt:158.344
# ##########Best model found so far##########
# Ep:25, loss:0.00017, loss_test:0.09587, lr:7.78e-03, fs:0.88000 (r=1.000,p=0.786),  time:6.349, tt:165.064
# Ep:26, loss:0.00016, loss_test:0.09384, lr:7.70e-03, fs:0.90164 (r=1.000,p=0.821),  time:6.348, tt:171.404
# ##########Best model found so far##########
# Ep:27, loss:0.00016, loss_test:0.09409, lr:7.62e-03, fs:0.92437 (r=1.000,p=0.859),  time:6.346, tt:177.700
# ##########Best model found so far##########
# Ep:28, loss:0.00016, loss_test:0.09146, lr:7.55e-03, fs:0.90756 (r=0.982,p=0.844),  time:6.303, tt:182.792
# Ep:29, loss:0.00015, loss_test:0.08948, lr:7.47e-03, fs:0.88000 (r=1.000,p=0.786),  time:6.268, tt:188.053
# Ep:30, loss:0.00015, loss_test:0.09088, lr:7.40e-03, fs:0.91667 (r=1.000,p=0.846),  time:6.256, tt:193.946
# Ep:31, loss:0.00014, loss_test:0.08070, lr:7.32e-03, fs:0.90164 (r=1.000,p=0.821),  time:6.256, tt:200.204
# Ep:32, loss:0.00013, loss_test:0.08262, lr:7.25e-03, fs:0.90909 (r=1.000,p=0.833),  time:6.278, tt:207.180
# Ep:33, loss:0.00014, loss_test:0.07631, lr:7.18e-03, fs:0.91667 (r=1.000,p=0.846),  time:6.254, tt:212.632
# Ep:34, loss:0.00014, loss_test:0.07938, lr:7.11e-03, fs:0.92437 (r=1.000,p=0.859),  time:6.238, tt:218.316
# Ep:35, loss:0.00014, loss_test:0.07461, lr:7.03e-03, fs:0.92437 (r=1.000,p=0.859),  time:6.213, tt:223.665
# Ep:36, loss:0.00013, loss_test:0.07507, lr:6.96e-03, fs:0.89431 (r=1.000,p=0.809),  time:6.196, tt:229.244
# Ep:37, loss:0.00012, loss_test:0.07186, lr:6.89e-03, fs:0.94828 (r=1.000,p=0.902),  time:6.185, tt:235.028
# ##########Best model found so far##########
# Ep:38, loss:0.00012, loss_test:0.06582, lr:6.83e-03, fs:0.92437 (r=1.000,p=0.859),  time:6.183, tt:241.137
# Ep:39, loss:0.00011, loss_test:0.07143, lr:6.76e-03, fs:0.91667 (r=1.000,p=0.846),  time:6.166, tt:246.657
# Ep:40, loss:0.00011, loss_test:0.06382, lr:6.69e-03, fs:0.94828 (r=1.000,p=0.902),  time:6.169, tt:252.918
# Ep:41, loss:0.00010, loss_test:0.06328, lr:6.62e-03, fs:0.94017 (r=1.000,p=0.887),  time:6.149, tt:258.247
# Ep:42, loss:0.00010, loss_test:0.06262, lr:6.56e-03, fs:0.91667 (r=1.000,p=0.846),  time:6.138, tt:263.919
# Ep:43, loss:0.00009, loss_test:0.06006, lr:6.49e-03, fs:0.94017 (r=1.000,p=0.887),  time:6.140, tt:270.156
# Ep:44, loss:0.00009, loss_test:0.05456, lr:6.43e-03, fs:0.95652 (r=1.000,p=0.917),  time:6.218, tt:279.825
# ##########Best model found so far##########
# Ep:45, loss:0.00009, loss_test:0.05746, lr:6.36e-03, fs:0.94828 (r=1.000,p=0.902),  time:6.283, tt:289.023
# Ep:46, loss:0.00009, loss_test:0.05517, lr:6.30e-03, fs:0.94017 (r=1.000,p=0.887),  time:6.293, tt:295.754
# Ep:47, loss:0.00008, loss_test:0.05487, lr:6.24e-03, fs:0.96491 (r=1.000,p=0.932),  time:6.285, tt:301.688
# ##########Best model found so far##########
# Ep:48, loss:0.00008, loss_test:0.05260, lr:6.17e-03, fs:0.95652 (r=1.000,p=0.917),  time:6.273, tt:307.366
# Ep:49, loss:0.00008, loss_test:0.05828, lr:6.11e-03, fs:0.94017 (r=1.000,p=0.887),  time:6.264, tt:313.185
# Ep:50, loss:0.00007, loss_test:0.05020, lr:6.05e-03, fs:0.94828 (r=1.000,p=0.902),  time:6.255, tt:318.983
# Ep:51, loss:0.00007, loss_test:0.04764, lr:5.99e-03, fs:0.95652 (r=1.000,p=0.917),  time:6.246, tt:324.786
# Ep:52, loss:0.00007, loss_test:0.04772, lr:5.93e-03, fs:0.95652 (r=1.000,p=0.917),  time:6.246, tt:331.024
# Ep:53, loss:0.00007, loss_test:0.04486, lr:5.87e-03, fs:0.94828 (r=1.000,p=0.902),  time:6.251, tt:337.537
# Ep:54, loss:0.00007, loss_test:0.04383, lr:5.81e-03, fs:0.95652 (r=1.000,p=0.917),  time:6.243, tt:343.347
# Ep:55, loss:0.00006, loss_test:0.04039, lr:5.75e-03, fs:0.96491 (r=1.000,p=0.932),  time:6.241, tt:349.497
# Ep:56, loss:0.00006, loss_test:0.04361, lr:5.70e-03, fs:0.96491 (r=1.000,p=0.932),  time:6.239, tt:355.644
# Ep:57, loss:0.00006, loss_test:0.04280, lr:5.64e-03, fs:0.96491 (r=1.000,p=0.932),  time:6.229, tt:361.263
# Ep:58, loss:0.00006, loss_test:0.04110, lr:5.58e-03, fs:0.96491 (r=1.000,p=0.932),  time:6.224, tt:367.232
# Ep:59, loss:0.00006, loss_test:0.04320, lr:5.53e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.220, tt:373.214
# ##########Best model found so far##########
# Ep:60, loss:0.00006, loss_test:0.04453, lr:5.47e-03, fs:0.95652 (r=1.000,p=0.917),  time:6.216, tt:379.185
# Ep:61, loss:0.00006, loss_test:0.03871, lr:5.42e-03, fs:0.96491 (r=1.000,p=0.932),  time:6.212, tt:385.117
# Ep:62, loss:0.00005, loss_test:0.04098, lr:5.36e-03, fs:0.95652 (r=1.000,p=0.917),  time:6.207, tt:391.053
# Ep:63, loss:0.00005, loss_test:0.03761, lr:5.31e-03, fs:0.96491 (r=1.000,p=0.932),  time:6.210, tt:397.459
# Ep:64, loss:0.00005, loss_test:0.04072, lr:5.26e-03, fs:0.96491 (r=1.000,p=0.932),  time:6.208, tt:403.525
# Ep:65, loss:0.00005, loss_test:0.03968, lr:5.20e-03, fs:0.96491 (r=1.000,p=0.932),  time:6.236, tt:411.572
# Ep:66, loss:0.00004, loss_test:0.03573, lr:5.15e-03, fs:0.96491 (r=1.000,p=0.932),  time:6.269, tt:420.032
# Ep:67, loss:0.00005, loss_test:0.03672, lr:5.10e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.298, tt:428.267
# Ep:68, loss:0.00005, loss_test:0.03558, lr:5.05e-03, fs:0.96491 (r=1.000,p=0.932),  time:6.297, tt:434.507
# Ep:69, loss:0.00004, loss_test:0.03363, lr:5.00e-03, fs:0.96491 (r=1.000,p=0.932),  time:6.296, tt:440.690
# Ep:70, loss:0.00004, loss_test:0.03579, lr:4.95e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.287, tt:446.391
# Ep:71, loss:0.00004, loss_test:0.03055, lr:4.90e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.287, tt:452.676
# Ep:72, loss:0.00004, loss_test:0.03164, lr:4.85e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.288, tt:459.012
# Ep:73, loss:0.00004, loss_test:0.03221, lr:4.80e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.285, tt:465.074
# Ep:74, loss:0.00004, loss_test:0.02910, lr:4.75e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.281, tt:471.068
# Ep:75, loss:0.00003, loss_test:0.02921, lr:4.71e-03, fs:0.96491 (r=1.000,p=0.932),  time:6.277, tt:477.082
# Ep:76, loss:0.00004, loss_test:0.02801, lr:4.66e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.273, tt:483.055
# ##########Best model found so far##########
# Ep:77, loss:0.00003, loss_test:0.02740, lr:4.61e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.271, tt:489.111
# Ep:78, loss:0.00003, loss_test:0.02704, lr:4.57e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.269, tt:495.264
# Ep:79, loss:0.00004, loss_test:0.02646, lr:4.52e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.264, tt:501.123
# Ep:80, loss:0.00003, loss_test:0.02686, lr:4.48e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.258, tt:506.898
# Ep:81, loss:0.00003, loss_test:0.02848, lr:4.43e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.258, tt:513.117
# Ep:82, loss:0.00003, loss_test:0.02629, lr:4.39e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.253, tt:519.023
# Ep:83, loss:0.00003, loss_test:0.02493, lr:4.34e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.248, tt:524.798
# Ep:84, loss:0.00003, loss_test:0.02505, lr:4.30e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.246, tt:530.892
# Ep:85, loss:0.00003, loss_test:0.02346, lr:4.26e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.247, tt:537.229
# Ep:86, loss:0.00002, loss_test:0.02465, lr:4.21e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.247, tt:543.472
# Ep:87, loss:0.00002, loss_test:0.02388, lr:4.17e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.285, tt:553.114
# Ep:88, loss:0.00002, loss_test:0.02351, lr:4.13e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.319, tt:562.355
# Ep:89, loss:0.00002, loss_test:0.02371, lr:4.09e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.326, tt:569.313
# Ep:90, loss:0.00002, loss_test:0.02204, lr:4.05e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.322, tt:575.311
# Ep:91, loss:0.00002, loss_test:0.02105, lr:4.01e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.316, tt:581.092
# Ep:92, loss:0.00002, loss_test:0.02254, lr:3.97e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.310, tt:586.845
# Ep:93, loss:0.00002, loss_test:0.02446, lr:3.93e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.306, tt:592.740
# Ep:94, loss:0.00002, loss_test:0.02198, lr:3.89e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.303, tt:598.791
# Ep:95, loss:0.00002, loss_test:0.02148, lr:3.85e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.300, tt:604.820
# Ep:96, loss:0.00002, loss_test:0.02091, lr:3.81e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.300, tt:611.060
# Ep:97, loss:0.00002, loss_test:0.02327, lr:3.77e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.292, tt:616.645
# Ep:98, loss:0.00002, loss_test:0.02122, lr:3.73e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.288, tt:622.555
# Ep:99, loss:0.00002, loss_test:0.01841, lr:3.70e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.283, tt:628.311
# Ep:100, loss:0.00002, loss_test:0.01714, lr:3.66e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.281, tt:634.359
# Ep:101, loss:0.00002, loss_test:0.01736, lr:3.62e-03, fs:0.99099 (r=1.000,p=0.982),  time:6.280, tt:640.592
# ##########Best model found so far##########
# Ep:102, loss:0.00001, loss_test:0.01696, lr:3.59e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.280, tt:646.791
# Ep:103, loss:0.00002, loss_test:0.01705, lr:3.55e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.273, tt:652.413
# Ep:104, loss:0.00001, loss_test:0.01657, lr:3.52e-03, fs:0.97345 (r=1.000,p=0.948),  time:6.270, tt:658.387
# Ep:105, loss:0.00001, loss_test:0.01624, lr:3.48e-03, fs:0.99099 (r=1.000,p=0.982),  time:6.265, tt:664.095
# Ep:106, loss:0.00001, loss_test:0.01661, lr:3.45e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.264, tt:670.216
# Ep:107, loss:0.00001, loss_test:0.01621, lr:3.41e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.261, tt:676.163
# Ep:108, loss:0.00001, loss_test:0.01610, lr:3.38e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.272, tt:683.625
# Ep:109, loss:0.00001, loss_test:0.01525, lr:3.34e-03, fs:0.99099 (r=1.000,p=0.982),  time:6.289, tt:691.752
# Ep:110, loss:0.00001, loss_test:0.01438, lr:3.31e-03, fs:0.99099 (r=1.000,p=0.982),  time:6.305, tt:699.902
# Ep:111, loss:0.00001, loss_test:0.01331, lr:3.28e-03, fs:0.99099 (r=1.000,p=0.982),  time:6.297, tt:705.213
# Ep:112, loss:0.00001, loss_test:0.01292, lr:3.24e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.283, tt:710.022
# Ep:113, loss:0.00001, loss_test:0.01357, lr:3.21e-03, fs:0.99099 (r=1.000,p=0.982),  time:6.270, tt:714.821
# Ep:114, loss:0.00001, loss_test:0.01406, lr:3.18e-03, fs:0.99099 (r=1.000,p=0.982),  time:6.270, tt:721.032
# Ep:115, loss:0.00001, loss_test:0.01435, lr:3.15e-03, fs:0.99099 (r=1.000,p=0.982),  time:6.269, tt:727.180
# Ep:116, loss:0.00001, loss_test:0.01383, lr:3.12e-03, fs:0.99099 (r=1.000,p=0.982),  time:6.270, tt:733.608
# Ep:117, loss:0.00001, loss_test:0.01297, lr:3.09e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.268, tt:739.625
# Ep:118, loss:0.00001, loss_test:0.01373, lr:3.05e-03, fs:0.98214 (r=1.000,p=0.965),  time:6.263, tt:745.329
# Ep:119, loss:0.00001, loss_test:0.01354, lr:3.02e-03, fs:0.99099 (r=1.000,p=0.982),  time:6.262, tt:751.448
# Model and results saved
# Saving best model...
# Model and results saved
# Values to load
# dataset_name=openML
# neg_sample= 0
# strategy= 10_cv
# create_new_split= False
# cross_v= 2
# Dataset splits loaded
# Train positive samples: 488 Test positive samples: 55
# Meta-feature graph from datasets loaded
# Start of training...NN Fasttext2_364 Loss CosineEmbeddingLoss Split 1024:
# Ep:0, loss:0.00061, loss_test:0.24709, lr:1.00e-02, fs:0.66667 (r=1.000,p=0.500),  time:6.195, tt:6.195
# ##########Best model found so far##########
# Ep:1, loss:0.00061, loss_test:0.24618, lr:9.90e-03, fs:0.66667 (r=1.000,p=0.500),  time:6.015, tt:12.029
# Ep:2, loss:0.00059, loss_test:0.24403, lr:9.80e-03, fs:0.66667 (r=1.000,p=0.500),  time:6.079, tt:18.237
# Ep:3, loss:0.00056, loss_test:0.23804, lr:9.70e-03, fs:0.66667 (r=1.000,p=0.500),  time:6.083, tt:24.332
# Ep:4, loss:0.00049, loss_test:0.22433, lr:9.61e-03, fs:0.64557 (r=0.927,p=0.495),  time:6.096, tt:30.479
# Ep:5, loss:0.00040, loss_test:0.22232, lr:9.51e-03, fs:0.60563 (r=0.782,p=0.494),  time:6.104, tt:36.624
# Ep:6, loss:0.00033, loss_test:0.22054, lr:9.41e-03, fs:0.61194 (r=0.745,p=0.519),  time:6.488, tt:45.419
# Ep:7, loss:0.00030, loss_test:0.21741, lr:9.32e-03, fs:0.61417 (r=0.709,p=0.542),  time:6.792, tt:54.334
# Ep:8, loss:0.00029, loss_test:0.21103, lr:9.23e-03, fs:0.65574 (r=0.727,p=0.597),  time:7.042, tt:63.380
# Ep:9, loss:0.00029, loss_test:0.20763, lr:9.14e-03, fs:0.63492 (r=0.727,p=0.563),  time:6.980, tt:69.800
# Ep:10, loss:0.00028, loss_test:0.20357, lr:9.04e-03, fs:0.66129 (r=0.745,p=0.594),  time:6.881, tt:75.690
# Ep:11, loss:0.00027, loss_test:0.19733, lr:8.95e-03, fs:0.67213 (r=0.745,p=0.612),  time:6.809, tt:81.702
# ##########Best model found so far##########
# Ep:12, loss:0.00026, loss_test:0.19314, lr:8.86e-03, fs:0.70492 (r=0.782,p=0.642),  time:6.772, tt:88.031
# ##########Best model found so far##########
# Ep:13, loss:0.00025, loss_test:0.19049, lr:8.78e-03, fs:0.71545 (r=0.800,p=0.647),  time:6.767, tt:94.736
# ##########Best model found so far##########
# Ep:14, loss:0.00024, loss_test:0.18516, lr:8.69e-03, fs:0.70400 (r=0.800,p=0.629),  time:6.713, tt:100.699
# Ep:15, loss:0.00024, loss_test:0.17935, lr:8.60e-03, fs:0.72881 (r=0.782,p=0.683),  time:6.671, tt:106.743
# ##########Best model found so far##########
# Ep:16, loss:0.00024, loss_test:0.17460, lr:8.51e-03, fs:0.70400 (r=0.800,p=0.629),  time:6.636, tt:112.816
# Ep:17, loss:0.00022, loss_test:0.17557, lr:8.43e-03, fs:0.69841 (r=0.800,p=0.620),  time:6.636, tt:119.457
# Ep:18, loss:0.00021, loss_test:0.16852, lr:8.35e-03, fs:0.75630 (r=0.818,p=0.703),  time:6.592, tt:125.243
# ##########Best model found so far##########
# Ep:19, loss:0.00021, loss_test:0.15999, lr:8.26e-03, fs:0.77419 (r=0.873,p=0.696),  time:6.593, tt:131.869
# ##########Best model found so far##########
# Ep:20, loss:0.00020, loss_test:0.16607, lr:8.18e-03, fs:0.72881 (r=0.782,p=0.683),  time:6.547, tt:137.485
# Ep:21, loss:0.00020, loss_test:0.15757, lr:8.10e-03, fs:0.79070 (r=0.927,p=0.689),  time:6.512, tt:143.270
# ##########Best model found so far##########
# Ep:22, loss:0.00019, loss_test:0.15640, lr:8.02e-03, fs:0.75806 (r=0.855,p=0.681),  time:6.494, tt:149.367
# Ep:23, loss:0.00019, loss_test:0.14689, lr:7.94e-03, fs:0.78740 (r=0.909,p=0.694),  time:6.459, tt:155.017
# Ep:24, loss:0.00017, loss_test:0.15502, lr:7.86e-03, fs:0.80342 (r=0.855,p=0.758),  time:6.426, tt:160.657
# ##########Best model found so far##########
# Ep:25, loss:0.00017, loss_test:0.14362, lr:7.78e-03, fs:0.80000 (r=0.909,p=0.714),  time:6.417, tt:166.851
# Ep:26, loss:0.00016, loss_test:0.14599, lr:7.70e-03, fs:0.83333 (r=0.909,p=0.769),  time:6.373, tt:172.072
# ##########Best model found so far##########
# Ep:27, loss:0.00016, loss_test:0.13941, lr:7.62e-03, fs:0.78740 (r=0.909,p=0.694),  time:6.382, tt:178.702
# Ep:28, loss:0.00016, loss_test:0.13742, lr:7.55e-03, fs:0.82353 (r=0.891,p=0.766),  time:6.465, tt:187.490
# Ep:29, loss:0.00015, loss_test:0.13189, lr:7.47e-03, fs:0.84034 (r=0.909,p=0.781),  time:6.519, tt:195.581
# ##########Best model found so far##########
# Ep:30, loss:0.00015, loss_test:0.13114, lr:7.40e-03, fs:0.82645 (r=0.909,p=0.758),  time:6.483, tt:200.959
# Ep:31, loss:0.00014, loss_test:0.12332, lr:7.32e-03, fs:0.85484 (r=0.964,p=0.768),  time:6.462, tt:206.793
# ##########Best model found so far##########
# Ep:32, loss:0.00014, loss_test:0.12736, lr:7.25e-03, fs:0.85470 (r=0.909,p=0.806),  time:6.436, tt:212.377
# Ep:33, loss:0.00014, loss_test:0.12137, lr:7.18e-03, fs:0.86885 (r=0.964,p=0.791),  time:6.429, tt:218.599
# ##########Best model found so far##########
# Ep:34, loss:0.00013, loss_test:0.12169, lr:7.11e-03, fs:0.85000 (r=0.927,p=0.785),  time:6.408, tt:224.291
# Ep:35, loss:0.00013, loss_test:0.11509, lr:7.03e-03, fs:0.87805 (r=0.982,p=0.794),  time:6.382, tt:229.742
# ##########Best model found so far##########
# Ep:36, loss:0.00013, loss_test:0.12187, lr:6.96e-03, fs:0.87179 (r=0.927,p=0.823),  time:6.362, tt:235.401
# Ep:37, loss:0.00012, loss_test:0.11106, lr:6.89e-03, fs:0.90000 (r=0.982,p=0.831),  time:6.342, tt:241.003
# ##########Best model found so far##########
# Ep:38, loss:0.00012, loss_test:0.10818, lr:6.83e-03, fs:0.90909 (r=1.000,p=0.833),  time:6.309, tt:246.065
# ##########Best model found so far##########
# Ep:39, loss:0.00011, loss_test:0.10937, lr:6.76e-03, fs:0.90756 (r=0.982,p=0.844),  time:6.293, tt:251.714
# Ep:40, loss:0.00011, loss_test:0.10938, lr:6.69e-03, fs:0.87931 (r=0.927,p=0.836),  time:6.276, tt:257.299
# Ep:41, loss:0.00011, loss_test:0.10498, lr:6.62e-03, fs:0.91667 (r=1.000,p=0.846),  time:6.258, tt:262.848
# ##########Best model found so far##########
# Ep:42, loss:0.00011, loss_test:0.09718, lr:6.56e-03, fs:0.91667 (r=1.000,p=0.846),  time:6.238, tt:268.235
# Ep:43, loss:0.00010, loss_test:0.09732, lr:6.49e-03, fs:0.90164 (r=1.000,p=0.821),  time:6.236, tt:274.371
# Ep:44, loss:0.00010, loss_test:0.09633, lr:6.43e-03, fs:0.89831 (r=0.964,p=0.841),  time:6.224, tt:280.058
# Ep:45, loss:0.00010, loss_test:0.09339, lr:6.36e-03, fs:0.90756 (r=0.982,p=0.844),  time:6.199, tt:285.163
# Ep:46, loss:0.00009, loss_test:0.09156, lr:6.30e-03, fs:0.90909 (r=1.000,p=0.833),  time:6.189, tt:290.903
# Ep:47, loss:0.00009, loss_test:0.08887, lr:6.24e-03, fs:0.91525 (r=0.982,p=0.857),  time:6.174, tt:296.360
# Ep:48, loss:0.00009, loss_test:0.08974, lr:6.17e-03, fs:0.90000 (r=0.982,p=0.831),  time:6.167, tt:302.189
# Ep:49, loss:0.00008, loss_test:0.08189, lr:6.11e-03, fs:0.89431 (r=1.000,p=0.809),  time:6.193, tt:309.671
# Ep:50, loss:0.00008, loss_test:0.08592, lr:6.05e-03, fs:0.90756 (r=0.982,p=0.844),  time:6.250, tt:318.765
# Ep:51, loss:0.00008, loss_test:0.08220, lr:5.99e-03, fs:0.89831 (r=0.964,p=0.841),  time:6.294, tt:327.314
# Ep:52, loss:0.00008, loss_test:0.07875, lr:5.93e-03, fs:0.89076 (r=0.964,p=0.828),  time:6.305, tt:334.155
# Ep:53, loss:0.00008, loss_test:0.08103, lr:5.87e-03, fs:0.90598 (r=0.964,p=0.855),  time:6.303, tt:340.346
# Ep:54, loss:0.00007, loss_test:0.07166, lr:5.81e-03, fs:0.90000 (r=0.982,p=0.831),  time:6.281, tt:345.431
# Ep:55, loss:0.00007, loss_test:0.07566, lr:5.75e-03, fs:0.90756 (r=0.982,p=0.844),  time:6.282, tt:351.795
# Ep:56, loss:0.00007, loss_test:0.07159, lr:5.70e-03, fs:0.90756 (r=0.982,p=0.844),  time:6.294, tt:358.766
# Ep:57, loss:0.00007, loss_test:0.06741, lr:5.64e-03, fs:0.91667 (r=1.000,p=0.846),  time:6.280, tt:364.223
# Ep:58, loss:0.00006, loss_test:0.06858, lr:5.58e-03, fs:0.89831 (r=0.964,p=0.841),  time:6.284, tt:370.727
# Ep:59, loss:0.00007, loss_test:0.06513, lr:5.53e-03, fs:0.91525 (r=0.982,p=0.857),  time:6.275, tt:376.483
# Ep:60, loss:0.00006, loss_test:0.06217, lr:5.47e-03, fs:0.90756 (r=0.982,p=0.844),  time:6.275, tt:382.785
# Ep:61, loss:0.00006, loss_test:0.06282, lr:5.42e-03, fs:0.91525 (r=0.982,p=0.857),  time:6.271, tt:388.796
# Ep:62, loss:0.00006, loss_test:0.06027, lr:5.36e-03, fs:0.92308 (r=0.982,p=0.871),  time:6.266, tt:394.728
# ##########Best model found so far##########
# Ep:63, loss:0.00005, loss_test:0.05773, lr:5.31e-03, fs:0.91525 (r=0.982,p=0.857),  time:6.261, tt:400.714
# Ep:64, loss:0.00005, loss_test:0.06008, lr:5.26e-03, fs:0.90000 (r=0.982,p=0.831),  time:6.260, tt:406.867
# Ep:65, loss:0.00005, loss_test:0.06036, lr:5.20e-03, fs:0.91525 (r=0.982,p=0.857),  time:6.254, tt:412.778
# Ep:66, loss:0.00005, loss_test:0.05513, lr:5.15e-03, fs:0.90598 (r=0.964,p=0.855),  time:6.254, tt:419.007
# Ep:67, loss:0.00005, loss_test:0.05556, lr:5.10e-03, fs:0.91525 (r=0.982,p=0.857),  time:6.251, tt:425.057
# Ep:68, loss:0.00005, loss_test:0.05217, lr:5.05e-03, fs:0.92308 (r=0.982,p=0.871),  time:6.253, tt:431.475
# Ep:69, loss:0.00005, loss_test:0.05018, lr:5.00e-03, fs:0.91525 (r=0.982,p=0.857),  time:6.254, tt:437.771
# Ep:70, loss:0.00005, loss_test:0.05301, lr:4.95e-03, fs:0.93103 (r=0.982,p=0.885),  time:6.280, tt:445.856
# ##########Best model found so far##########
# Ep:71, loss:0.00005, loss_test:0.04991, lr:4.90e-03, fs:0.91525 (r=0.982,p=0.857),  time:6.320, tt:455.054
# Ep:72, loss:0.00004, loss_test:0.04647, lr:4.85e-03, fs:0.92308 (r=0.982,p=0.871),  time:6.360, tt:464.265
# Ep:73, loss:0.00004, loss_test:0.04686, lr:4.80e-03, fs:0.91525 (r=0.982,p=0.857),  time:6.363, tt:470.831
# Ep:74, loss:0.00004, loss_test:0.04588, lr:4.75e-03, fs:0.94828 (r=1.000,p=0.902),  time:6.355, tt:476.604
# ##########Best model found so far##########
# Ep:75, loss:0.00004, loss_test:0.04313, lr:4.71e-03, fs:0.93103 (r=0.982,p=0.885),  time:6.349, tt:482.544
# Ep:76, loss:0.00004, loss_test:0.04127, lr:4.66e-03, fs:0.93103 (r=0.982,p=0.885),  time:6.342, tt:488.351
# Ep:77, loss:0.00004, loss_test:0.04283, lr:4.61e-03, fs:0.92174 (r=0.964,p=0.883),  time:6.343, tt:494.732
# Ep:78, loss:0.00003, loss_test:0.04103, lr:4.57e-03, fs:0.93220 (r=1.000,p=0.873),  time:6.335, tt:500.471
# Ep:79, loss:0.00003, loss_test:0.03927, lr:4.52e-03, fs:0.93913 (r=0.982,p=0.900),  time:6.328, tt:506.208
# Ep:80, loss:0.00003, loss_test:0.03918, lr:4.48e-03, fs:0.93103 (r=0.982,p=0.885),  time:6.327, tt:512.507
# Ep:81, loss:0.00003, loss_test:0.04099, lr:4.43e-03, fs:0.92982 (r=0.964,p=0.898),  time:6.319, tt:518.125
# Ep:82, loss:0.00003, loss_test:0.03968, lr:4.39e-03, fs:0.92174 (r=0.964,p=0.883),  time:6.318, tt:524.411
# Ep:83, loss:0.00003, loss_test:0.03623, lr:4.34e-03, fs:0.93103 (r=0.982,p=0.885),  time:6.313, tt:530.327
# Ep:84, loss:0.00003, loss_test:0.03552, lr:4.30e-03, fs:0.92982 (r=0.964,p=0.898),  time:6.305, tt:535.923
# Ep:85, loss:0.00003, loss_test:0.03497, lr:4.26e-03, fs:0.92174 (r=0.964,p=0.883),  time:6.301, tt:541.903
# Ep:86, loss:0.00003, loss_test:0.03548, lr:4.21e-03, fs:0.92982 (r=0.964,p=0.898),  time:6.295, tt:547.699
# Ep:87, loss:0.00003, loss_test:0.03447, lr:4.17e-03, fs:0.92174 (r=0.964,p=0.883),  time:6.286, tt:553.145
# Ep:88, loss:0.00003, loss_test:0.03277, lr:4.13e-03, fs:0.93103 (r=0.982,p=0.885),  time:6.286, tt:559.429
# Ep:89, loss:0.00002, loss_test:0.03072, lr:4.09e-03, fs:0.93913 (r=0.982,p=0.900),  time:6.279, tt:565.108
# Ep:90, loss:0.00002, loss_test:0.03098, lr:4.05e-03, fs:0.92174 (r=0.964,p=0.883),  time:6.265, tt:570.156
# Ep:91, loss:0.00002, loss_test:0.03164, lr:4.01e-03, fs:0.93103 (r=0.982,p=0.885),  time:6.285, tt:578.211
# Ep:92, loss:0.00002, loss_test:0.03135, lr:3.97e-03, fs:0.92982 (r=0.964,p=0.898),  time:6.315, tt:587.287
# Ep:93, loss:0.00002, loss_test:0.03032, lr:3.93e-03, fs:0.93805 (r=0.964,p=0.914),  time:6.339, tt:595.884
# Ep:94, loss:0.00002, loss_test:0.03093, lr:3.89e-03, fs:0.92982 (r=0.964,p=0.898),  time:6.328, tt:601.129
# Ep:95, loss:0.00002, loss_test:0.02685, lr:3.85e-03, fs:0.94737 (r=0.982,p=0.915),  time:6.323, tt:606.989
# Ep:96, loss:0.00002, loss_test:0.02694, lr:3.81e-03, fs:0.93103 (r=0.982,p=0.885),  time:6.318, tt:612.809
# Ep:97, loss:0.00002, loss_test:0.02650, lr:3.77e-03, fs:0.94643 (r=0.964,p=0.930),  time:6.310, tt:618.408
# Ep:98, loss:0.00002, loss_test:0.02823, lr:3.73e-03, fs:0.93805 (r=0.964,p=0.914),  time:6.307, tt:624.363
# Ep:99, loss:0.00002, loss_test:0.02690, lr:3.70e-03, fs:0.94643 (r=0.964,p=0.930),  time:6.304, tt:630.417
# Ep:100, loss:0.00002, loss_test:0.02842, lr:3.66e-03, fs:0.92982 (r=0.964,p=0.898),  time:6.301, tt:636.400
# Ep:101, loss:0.00002, loss_test:0.02595, lr:3.62e-03, fs:0.95495 (r=0.964,p=0.946),  time:6.296, tt:642.205
# ##########Best model found so far##########
# Ep:102, loss:0.00002, loss_test:0.02637, lr:3.59e-03, fs:0.93805 (r=0.964,p=0.914),  time:6.291, tt:647.948
# Ep:103, loss:0.00002, loss_test:0.02702, lr:3.55e-03, fs:0.93805 (r=0.964,p=0.914),  time:6.285, tt:653.691
# Ep:104, loss:0.00002, loss_test:0.02682, lr:3.52e-03, fs:0.95495 (r=0.964,p=0.946),  time:6.283, tt:659.727
# Ep:105, loss:0.00002, loss_test:0.02403, lr:3.48e-03, fs:0.95495 (r=0.964,p=0.946),  time:6.277, tt:665.385
# Ep:106, loss:0.00002, loss_test:0.02433, lr:3.45e-03, fs:0.94643 (r=0.964,p=0.930),  time:6.271, tt:670.969
# Ep:107, loss:0.00001, loss_test:0.02353, lr:3.41e-03, fs:0.94643 (r=0.964,p=0.930),  time:6.271, tt:677.221
# Ep:108, loss:0.00001, loss_test:0.02408, lr:3.38e-03, fs:0.94643 (r=0.964,p=0.930),  time:6.276, tt:684.039
# Ep:109, loss:0.00002, loss_test:0.02335, lr:3.34e-03, fs:0.95495 (r=0.964,p=0.946),  time:6.277, tt:690.432
# Ep:110, loss:0.00001, loss_test:0.02305, lr:3.31e-03, fs:0.95495 (r=0.964,p=0.946),  time:6.265, tt:695.397
# Ep:111, loss:0.00001, loss_test:0.02203, lr:3.28e-03, fs:0.95495 (r=0.964,p=0.946),  time:6.253, tt:700.326
# Ep:112, loss:0.00001, loss_test:0.02290, lr:3.24e-03, fs:0.92982 (r=0.964,p=0.898),  time:6.249, tt:706.123
# Ep:113, loss:0.00001, loss_test:0.02218, lr:3.21e-03, fs:0.93805 (r=0.964,p=0.914),  time:6.269, tt:714.635
# Ep:114, loss:0.00001, loss_test:0.02088, lr:3.18e-03, fs:0.94643 (r=0.964,p=0.930),  time:6.287, tt:723.019
# Ep:115, loss:0.00001, loss_test:0.02181, lr:3.15e-03, fs:0.94643 (r=0.964,p=0.930),  time:6.292, tt:729.856
# Ep:116, loss:0.00001, loss_test:0.02265, lr:3.12e-03, fs:0.93805 (r=0.964,p=0.914),  time:6.292, tt:736.118
# Ep:117, loss:0.00001, loss_test:0.02187, lr:3.09e-03, fs:0.94643 (r=0.964,p=0.930),  time:6.290, tt:742.234
# Ep:118, loss:0.00001, loss_test:0.02107, lr:3.05e-03, fs:0.94643 (r=0.964,p=0.930),  time:6.291, tt:748.586
# Ep:119, loss:0.00001, loss_test:0.02223, lr:3.02e-03, fs:0.93805 (r=0.964,p=0.914),  time:6.287, tt:754.398
# Model and results saved
# Saving best model...
# Model and results saved
# Values to load
# dataset_name=openML
# neg_sample= 0
# strategy= 10_cv
# create_new_split= False
# cross_v= 3
# Dataset splits loaded
# Train positive samples: 489 Test positive samples: 54
# Meta-feature graph from datasets loaded
# Start of training...NN Fasttext2_364 Loss CosineEmbeddingLoss Split 1024:
# /home/pablo/gcnsm/step3v2/step3_gcnsm.py:308: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(result)
# Ep:0, loss:0.00061, loss_test:0.24676, lr:1.00e-02, fs:0.66667 (r=1.000,p=0.500),  time:5.941, tt:5.941
# ##########Best model found so far##########
# Ep:1, loss:0.00061, loss_test:0.24562, lr:9.90e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.934, tt:11.869
# Ep:2, loss:0.00059, loss_test:0.24308, lr:9.80e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.867, tt:17.600
# Ep:3, loss:0.00056, loss_test:0.23733, lr:9.70e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.866, tt:23.463
# Ep:4, loss:0.00050, loss_test:0.22586, lr:9.61e-03, fs:0.64968 (r=0.944,p=0.495),  time:5.800, tt:28.999
# Ep:5, loss:0.00040, loss_test:0.21580, lr:9.51e-03, fs:0.63448 (r=0.852,p=0.505),  time:5.783, tt:34.698
# Ep:6, loss:0.00032, loss_test:0.20933, lr:9.41e-03, fs:0.64615 (r=0.778,p=0.553),  time:5.773, tt:40.414
# Ep:7, loss:0.00031, loss_test:0.20594, lr:9.32e-03, fs:0.64957 (r=0.704,p=0.603),  time:5.857, tt:46.854
# Ep:8, loss:0.00029, loss_test:0.20064, lr:9.23e-03, fs:0.65600 (r=0.759,p=0.577),  time:5.845, tt:52.609
# Ep:9, loss:0.00029, loss_test:0.19631, lr:9.14e-03, fs:0.67797 (r=0.741,p=0.625),  time:5.818, tt:58.177
# ##########Best model found so far##########
# Ep:10, loss:0.00027, loss_test:0.19448, lr:9.04e-03, fs:0.71560 (r=0.722,p=0.709),  time:5.803, tt:63.829
# ##########Best model found so far##########
# Ep:11, loss:0.00027, loss_test:0.18330, lr:8.95e-03, fs:0.70492 (r=0.796,p=0.632),  time:5.962, tt:71.540
# Ep:12, loss:0.00026, loss_test:0.17835, lr:8.86e-03, fs:0.76190 (r=0.889,p=0.667),  time:6.107, tt:79.389
# ##########Best model found so far##########
# Ep:13, loss:0.00026, loss_test:0.17622, lr:8.78e-03, fs:0.77586 (r=0.833,p=0.726),  time:6.259, tt:87.628
# ##########Best model found so far##########
# Ep:14, loss:0.00026, loss_test:0.17337, lr:8.69e-03, fs:0.77419 (r=0.889,p=0.686),  time:6.236, tt:93.540
# Ep:15, loss:0.00024, loss_test:0.16531, lr:8.60e-03, fs:0.76667 (r=0.852,p=0.697),  time:6.207, tt:99.306
# Ep:16, loss:0.00023, loss_test:0.15695, lr:8.51e-03, fs:0.77686 (r=0.870,p=0.701),  time:6.160, tt:104.719
# ##########Best model found so far##########
# Ep:17, loss:0.00022, loss_test:0.15622, lr:8.43e-03, fs:0.79339 (r=0.889,p=0.716),  time:6.118, tt:110.119
# ##########Best model found so far##########
# Ep:18, loss:0.00021, loss_test:0.15184, lr:8.35e-03, fs:0.82759 (r=0.889,p=0.774),  time:6.073, tt:115.380
# ##########Best model found so far##########
# Ep:19, loss:0.00021, loss_test:0.14454, lr:8.26e-03, fs:0.79070 (r=0.944,p=0.680),  time:6.046, tt:120.922
# Ep:20, loss:0.00020, loss_test:0.15029, lr:8.18e-03, fs:0.85217 (r=0.907,p=0.803),  time:6.010, tt:126.206
# ##########Best model found so far##########
# Ep:21, loss:0.00020, loss_test:0.13668, lr:8.10e-03, fs:0.81890 (r=0.963,p=0.712),  time:5.984, tt:131.638
# Ep:22, loss:0.00019, loss_test:0.13344, lr:8.02e-03, fs:0.84298 (r=0.944,p=0.761),  time:5.989, tt:137.743
# Ep:23, loss:0.00018, loss_test:0.13278, lr:7.94e-03, fs:0.85714 (r=0.944,p=0.785),  time:5.972, tt:143.338
# ##########Best model found so far##########
# Ep:24, loss:0.00018, loss_test:0.12636, lr:7.86e-03, fs:0.88136 (r=0.963,p=0.812),  time:5.965, tt:149.126
# ##########Best model found so far##########
# Ep:25, loss:0.00017, loss_test:0.12355, lr:7.78e-03, fs:0.86667 (r=0.963,p=0.788),  time:5.943, tt:154.522
# Ep:26, loss:0.00016, loss_test:0.12115, lr:7.70e-03, fs:0.89831 (r=0.981,p=0.828),  time:5.926, tt:159.990
# ##########Best model found so far##########
# Ep:27, loss:0.00016, loss_test:0.11561, lr:7.62e-03, fs:0.88136 (r=0.963,p=0.812),  time:5.921, tt:165.787
# Ep:28, loss:0.00015, loss_test:0.11503, lr:7.55e-03, fs:0.85950 (r=0.963,p=0.776),  time:5.902, tt:171.160
# Ep:29, loss:0.00015, loss_test:0.11364, lr:7.47e-03, fs:0.90598 (r=0.981,p=0.841),  time:5.875, tt:176.258
# ##########Best model found so far##########
# Ep:30, loss:0.00015, loss_test:0.10777, lr:7.40e-03, fs:0.89256 (r=1.000,p=0.806),  time:5.863, tt:181.756
# Ep:31, loss:0.00015, loss_test:0.10748, lr:7.32e-03, fs:0.92174 (r=0.981,p=0.869),  time:5.858, tt:187.457
# ##########Best model found so far##########
# Ep:32, loss:0.00015, loss_test:0.10342, lr:7.25e-03, fs:0.88333 (r=0.981,p=0.803),  time:5.879, tt:194.008
# Ep:33, loss:0.00014, loss_test:0.10037, lr:7.18e-03, fs:0.92857 (r=0.963,p=0.897),  time:5.948, tt:202.248
# ##########Best model found so far##########
# Ep:34, loss:0.00013, loss_test:0.09691, lr:7.11e-03, fs:0.86400 (r=1.000,p=0.761),  time:6.014, tt:210.494
# Ep:35, loss:0.00013, loss_test:0.10324, lr:7.03e-03, fs:0.90598 (r=0.981,p=0.841),  time:6.022, tt:216.810
# Ep:36, loss:0.00013, loss_test:0.09417, lr:6.96e-03, fs:0.90756 (r=1.000,p=0.831),  time:6.028, tt:223.047
# Ep:37, loss:0.00012, loss_test:0.09008, lr:6.89e-03, fs:0.92308 (r=1.000,p=0.857),  time:6.013, tt:228.498
# Ep:38, loss:0.00011, loss_test:0.09146, lr:6.83e-03, fs:0.90598 (r=0.981,p=0.841),  time:6.001, tt:234.027
# Ep:39, loss:0.00012, loss_test:0.08687, lr:6.76e-03, fs:0.91525 (r=1.000,p=0.844),  time:5.992, tt:239.683
# Ep:40, loss:0.00011, loss_test:0.08419, lr:6.69e-03, fs:0.93103 (r=1.000,p=0.871),  time:5.973, tt:244.907
# ##########Best model found so far##########
# Ep:41, loss:0.00011, loss_test:0.08380, lr:6.62e-03, fs:0.93103 (r=1.000,p=0.871),  time:5.969, tt:250.695
# Ep:42, loss:0.00011, loss_test:0.07882, lr:6.56e-03, fs:0.92308 (r=1.000,p=0.857),  time:5.959, tt:256.230
# ...
# Ep:105, loss:0.00001, loss_test:0.02017, lr:3.48e-03, fs:0.99065 (r=0.981,p=1.000),  time:5.869, tt:622.061
# Ep:106, loss:0.00001, loss_test:0.02043, lr:3.45e-03, fs:0.98148 (r=0.981,p=0.981),  time:5.870, tt:628.067
# Ep:107, loss:0.00001, loss_test:0.02044, lr:3.41e-03, fs:0.95495 (r=0.981,p=0.930),  time:5.865, tt:633.375
# Ep:108, loss:0.00001, loss_test:0.01927, lr:3.38e-03, fs:0.97248 (r=0.981,p=0.964),  time:5.860, tt:638.762
# Ep:109, loss:0.00001, loss_test:0.01872, lr:3.34e-03, fs:0.99065 (r=0.981,p=1.000),  time:5.857, tt:644.289
# Ep:110, loss:0.00001, loss_test:0.01787, lr:3.31e-03, fs:0.99065 (r=0.981,p=1.000),  time:5.860, tt:650.444
# Ep:111, loss:0.00001, loss_test:0.01864, lr:3.28e-03, fs:0.98148 (r=0.981,p=0.981),  time:5.863, tt:656.665
# Ep:112, loss:0.00001, loss_test:0.01702, lr:3.24e-03, fs:0.98148 (r=0.981,p=0.981),  time:5.867, tt:662.938
# Ep:113, loss:0.00001, loss_test:0.01662, lr:3.21e-03, fs:0.98148 (r=0.981,p=0.981),  time:5.868, tt:668.960
# Ep:114, loss:0.00001, loss_test:0.01707, lr:3.18e-03, fs:0.98148 (r=0.981,p=0.981),  time:5.870, tt:675.083
# Ep:115, loss:0.00001, loss_test:0.01681, lr:3.15e-03, fs:0.98148 (r=0.981,p=0.981),  time:5.880, tt:682.036
# Ep:116, loss:0.00001, loss_test:0.01504, lr:3.12e-03, fs:0.99065 (r=0.981,p=1.000),  time:5.888, tt:688.952
# Ep:117, loss:0.00001, loss_test:0.01504, lr:3.09e-03, fs:0.99065 (r=0.981,p=1.000),  time:5.893, tt:695.336
# Ep:118, loss:0.00001, loss_test:0.01633, lr:3.05e-03, fs:0.98148 (r=0.981,p=0.981),  time:5.896, tt:701.599
# Ep:119, loss:0.00001, loss_test:0.01664, lr:3.02e-03, fs:0.98148 (r=0.981,p=0.981),  time:5.897, tt:707.652
# Model and results saved
# Saving best model...
# Model and results saved
# Values to load
# dataset_name=openML
# neg_sample= 0
# strategy= 10_cv
# create_new_split= False
# cross_v= 9
# Dataset splits loaded
# Train positive samples: 489 Test positive samples: 54
# Meta-feature graph from datasets loaded
# Start of training...NN Fasttext2_364 Loss CosineEmbeddingLoss Split 1024:
# Ep:0, loss:0.00061, loss_test:0.23666, lr:1.00e-02, fs:0.66667 (r=1.000,p=0.500),  time:5.999, tt:5.999
# ##########Best model found so far##########
# Ep:1, loss:0.00061, loss_test:0.23285, lr:9.90e-03, fs:0.66667 (r=1.000,p=0.500),  time:6.006, tt:12.013
# Ep:2, loss:0.00059, loss_test:0.22511, lr:9.80e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.829, tt:17.486
# Ep:3, loss:0.00057, loss_test:0.20969, lr:9.70e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.717, tt:22.868
# Ep:4, loss:0.00051, loss_test:0.18234, lr:9.61e-03, fs:0.67925 (r=1.000,p=0.514),  time:5.595, tt:27.974
# ##########Best model found so far##########
# Ep:5, loss:0.00042, loss_test:0.16910, lr:9.51e-03, fs:0.68571 (r=0.889,p=0.558),  time:5.613, tt:33.676
# ##########Best model found so far##########
# Ep:6, loss:0.00033, loss_test:0.17030, lr:9.41e-03, fs:0.70677 (r=0.870,p=0.595),  time:5.577, tt:39.039
# ##########Best model found so far##########
# Ep:7, loss:0.00032, loss_test:0.16998, lr:9.32e-03, fs:0.75200 (r=0.870,p=0.662),  time:5.566, tt:44.532
# ##########Best model found so far##########
# Ep:8, loss:0.00030, loss_test:0.16904, lr:9.23e-03, fs:0.77049 (r=0.870,p=0.691),  time:5.522, tt:49.701
# ##########Best model found so far##########
# Ep:9, loss:0.00029, loss_test:0.16217, lr:9.14e-03, fs:0.77049 (r=0.870,p=0.691),  time:5.492, tt:54.917
# Ep:10, loss:0.00028, loss_test:0.15968, lr:9.04e-03, fs:0.79661 (r=0.870,p=0.734),  time:5.473, tt:60.207
# ##########Best model found so far##########
# Ep:11, loss:0.00027, loss_test:0.15789, lr:8.95e-03, fs:0.79310 (r=0.852,p=0.742),  time:5.533, tt:66.395
# Ep:12, loss:0.00026, loss_test:0.15427, lr:8.86e-03, fs:0.78992 (r=0.870,p=0.723),  time:5.563, tt:72.320
# Ep:13, loss:0.00025, loss_test:0.15537, lr:8.78e-03, fs:0.81356 (r=0.889,p=0.750),  time:5.558, tt:77.806
# ##########Best model found so far##########
# Ep:14, loss:0.00025, loss_test:0.15112, lr:8.69e-03, fs:0.81034 (r=0.870,p=0.758),  time:5.564, tt:83.459
# Ep:15, loss:0.00023, loss_test:0.14882, lr:8.60e-03, fs:0.82353 (r=0.907,p=0.754),  time:5.585, tt:89.357
# ##########Best model found so far##########
# Ep:16, loss:0.00022, loss_test:0.14278, lr:8.51e-03, fs:0.83200 (r=0.963,p=0.732),  time:5.558, tt:94.493
# ##########Best model found so far##########
# Ep:17, loss:0.00022, loss_test:0.14394, lr:8.43e-03, fs:0.84483 (r=0.907,p=0.790),  time:5.549, tt:99.889
# ##########Best model found so far##########
# Ep:18, loss:0.00021, loss_test:0.13532, lr:8.35e-03, fs:0.83871 (r=0.963,p=0.743),  time:5.545, tt:105.360
# Ep:19, loss:0.00021, loss_test:0.13523, lr:8.26e-03, fs:0.85000 (r=0.944,p=0.773),  time:5.542, tt:110.831
# ##########Best model found so far##########
# Ep:20, loss:0.00020, loss_test:0.13183, lr:8.18e-03, fs:0.85950 (r=0.963,p=0.776),  time:5.540, tt:116.350
# ##########Best model found so far##########
# Ep:21, loss:0.00019, loss_test:0.12989, lr:8.10e-03, fs:0.85000 (r=0.944,p=0.773),  time:5.529, tt:121.643
# Ep:22, loss:0.00018, loss_test:0.12971, lr:8.02e-03, fs:0.85714 (r=0.944,p=0.785),  time:5.519, tt:126.939
# Ep:23, loss:0.00018, loss_test:0.12445, lr:7.94e-03, fs:0.85246 (r=0.963,p=0.765),  time:5.523, tt:132.544
# Ep:24, loss:0.00018, loss_test:0.12144, lr:7.86e-03, fs:0.87179 (r=0.944,p=0.810),  time:5.572, tt:139.288
# ##########Best model found so far##########
# Ep:25, loss:0.00017, loss_test:0.11889, lr:7.78e-03, fs:0.85000 (r=0.944,p=0.773),  time:5.600, tt:145.604
# Ep:26, loss:0.00016, loss_test:0.12020, lr:7.70e-03, fs:0.88696 (r=0.944,p=0.836),  time:5.616, tt:151.625
# ##########Best model found so far##########
# Ep:27, loss:0.00016, loss_test:0.11331, lr:7.62e-03, fs:0.82540 (r=0.963,p=0.722),  time:5.641, tt:157.957
# Ep:28, loss:0.00015, loss_test:0.11504, lr:7.55e-03, fs:0.87719 (r=0.926,p=0.833),  time:5.642, tt:163.625
# Ep:29, loss:0.00015, loss_test:0.10796, lr:7.47e-03, fs:0.86441 (r=0.944,p=0.797),  time:5.651, tt:169.515
# Ep:30, loss:0.00015, loss_test:0.10475, lr:7.40e-03, fs:0.90265 (r=0.944,p=0.864),  time:5.666, tt:175.650
# ##########Best model found so far##########
# Ep:31, loss:0.00014, loss_test:0.10291, lr:7.32e-03, fs:0.84127 (r=0.981,p=0.736),  time:5.656, tt:181.008
# Ep:32, loss:0.00014, loss_test:0.10740, lr:7.25e-03, fs:0.88696 (r=0.944,p=0.836),  time:5.668, tt:187.055
# Ep:33, loss:0.00014, loss_test:0.10242, lr:7.18e-03, fs:0.84800 (r=0.981,p=0.746),  time:5.658, tt:192.363
# Ep:34, loss:0.00013, loss_test:0.10102, lr:7.11e-03, fs:0.90090 (r=0.926,p=0.877),  time:5.647, tt:197.649
# Ep:35, loss:0.00012, loss_test:0.09970, lr:7.03e-03, fs:0.89076 (r=0.981,p=0.815),  time:5.656, tt:203.616
# Ep:36, loss:0.00013, loss_test:0.09592, lr:6.96e-03, fs:0.91228 (r=0.963,p=0.867),  time:5.654, tt:209.182
# ##########Best model found so far##########
# Ep:37, loss:0.00012, loss_test:0.09158, lr:6.89e-03, fs:0.84127 (r=0.981,p=0.736),  time:5.642, tt:214.394
# Ep:38, loss:0.00012, loss_test:0.10381, lr:6.83e-03, fs:0.91892 (r=0.944,p=0.895),  time:5.637, tt:219.836
# ##########Best model found so far##########
# Ep:39, loss:0.00012, loss_test:0.09931, lr:6.76e-03, fs:0.86179 (r=0.981,p=0.768),  time:5.627, tt:225.079
# Ep:40, loss:0.00012, loss_test:0.09384, lr:6.69e-03, fs:0.93805 (r=0.981,p=0.898),  time:5.642, tt:231.304
# ##########Best model found so far##########
# Ep:41, loss:0.00011, loss_test:0.08933, lr:6.62e-03, fs:0.87603 (r=0.981,p=0.791),  time:5.641, tt:236.927
# Ep:42, loss:0.00011, loss_test:0.08772, lr:6.56e-03, fs:0.92982 (r=0.981,p=0.883),  time:5.631, tt:242.150
# Ep:43, loss:0.00011, loss_test:0.08417, lr:6.49e-03, fs:0.87603 (r=0.981,p=0.791),  time:5.642, tt:248.267
# Ep:44, loss:0.00010, loss_test:0.08423, lr:6.43e-03, fs:0.92982 (r=0.981,p=0.883),  time:5.647, tt:254.135
# Ep:45, loss:0.00010, loss_test:0.08364, lr:6.36e-03, fs:0.91379 (r=0.981,p=0.855),  time:5.648, tt:259.803
# Ep:46, loss:0.00010, loss_test:0.08106, lr:6.30e-03, fs:0.89655 (r=0.963,p=0.839),  time:5.656, tt:265.847
# Ep:47, loss:0.00010, loss_test:0.08002, lr:6.24e-03, fs:0.92035 (r=0.963,p=0.881),  time:5.650, tt:271.192
# Ep:48, loss:0.00009, loss_test:0.07958, lr:6.17e-03, fs:0.92982 (r=0.981,p=0.883),  time:5.647, tt:276.687
# Ep:49, loss:0.00009, loss_test:0.07905, lr:6.11e-03, fs:0.91228 (r=0.963,p=0.867),  time:5.647, tt:282.339
# Ep:50, loss:0.00009, loss_test:0.07462, lr:6.05e-03, fs:0.88889 (r=0.963,p=0.825),  time:5.646, tt:287.953
# Ep:51, loss:0.00008, loss_test:0.07590, lr:5.99e-03, fs:0.90598 (r=0.981,p=0.841),  time:5.647, tt:293.647
# Ep:52, loss:0.00008, loss_test:0.07764, lr:5.93e-03, fs:0.92727 (r=0.944,p=0.911),  time:5.660, tt:299.999
# Ep:53, loss:0.00008, loss_test:0.07029, lr:5.87e-03, fs:0.89076 (r=0.981,p=0.815),  time:5.665, tt:305.928
# Ep:54, loss:0.00008, loss_test:0.07071, lr:5.81e-03, fs:0.92174 (r=0.981,p=0.869),  time:5.672, tt:311.980
# Ep:55, loss:0.00008, loss_test:0.07487, lr:5.75e-03, fs:0.92035 (r=0.963,p=0.881),  time:5.690, tt:318.634
# Ep:56, loss:0.00008, loss_test:0.06519, lr:5.70e-03, fs:0.91228 (r=0.963,p=0.867),  time:5.682, tt:323.871
# Ep:57, loss:0.00008, loss_test:0.06299, lr:5.64e-03, fs:0.92857 (r=0.963,p=0.897),  time:5.683, tt:329.628
# Ep:58, loss:0.00007, loss_test:0.06350, lr:5.58e-03, fs:0.91228 (r=0.963,p=0.867),  time:5.683, tt:335.283
# Ep:59, loss:0.00007, loss_test:0.07099, lr:5.53e-03, fs:0.91892 (r=0.944,p=0.895),  time:5.685, tt:341.111
# Ep:60, loss:0.00007, loss_test:0.06607, lr:5.47e-03, fs:0.91892 (r=0.944,p=0.895),  time:5.684, tt:346.696
# Ep:61, loss:0.00007, loss_test:0.05899, lr:5.42e-03, fs:0.91228 (r=0.963,p=0.867),  time:5.680, tt:352.133
# Ep:62, loss:0.00006, loss_test:0.06212, lr:5.36e-03, fs:0.90435 (r=0.963,p=0.852),  time:5.681, tt:357.902
# Ep:63, loss:0.00006, loss_test:0.06064, lr:5.31e-03, fs:0.92035 (r=0.963,p=0.881),  time:5.691, tt:364.230
# Ep:64, loss:0.00006, loss_test:0.05934, lr:5.26e-03, fs:0.92035 (r=0.963,p=0.881),  time:5.688, tt:369.730
# Ep:65, loss:0.00006, loss_test:0.05625, lr:5.20e-03, fs:0.92035 (r=0.963,p=0.881),  time:5.684, tt:375.161
# Ep:66, loss:0.00006, loss_test:0.05522, lr:5.15e-03, fs:0.92857 (r=0.963,p=0.897),  time:5.681, tt:380.619
# Ep:67, loss:0.00005, loss_test:0.05553, lr:5.10e-03, fs:0.92035 (r=0.963,p=0.881),  time:5.684, tt:386.536
# Ep:68, loss:0.00005, loss_test:0.05462, lr:5.05e-03, fs:0.92857 (r=0.963,p=0.897),  time:5.684, tt:392.173
# Ep:69, loss:0.00005, loss_test:0.05707, lr:5.00e-03, fs:0.93694 (r=0.963,p=0.912),  time:5.698, tt:398.844
# Ep:70, loss:0.00005, loss_test:0.05511, lr:4.95e-03, fs:0.91228 (r=0.963,p=0.867),  time:5.705, tt:405.062
# Ep:71, loss:0.00005, loss_test:0.05100, lr:4.90e-03, fs:0.94545 (r=0.963,p=0.929),  time:5.700, tt:410.432
# ##########Best model found so far##########
# Ep:72, loss:0.00005, loss_test:0.04969, lr:4.85e-03, fs:0.91228 (r=0.963,p=0.867),  time:5.697, tt:415.873
# Ep:73, loss:0.00005, loss_test:0.05260, lr:4.80e-03, fs:0.93694 (r=0.963,p=0.912),  time:5.698, tt:421.661
# Ep:74, loss:0.00004, loss_test:0.05304, lr:4.75e-03, fs:0.93694 (r=0.963,p=0.912),  time:5.701, tt:427.587
# Ep:75, loss:0.00005, loss_test:0.05156, lr:4.71e-03, fs:0.91071 (r=0.944,p=0.879),  time:5.696, tt:432.895
# Ep:76, loss:0.00004, loss_test:0.05053, lr:4.66e-03, fs:0.94545 (r=0.963,p=0.929),  time:5.696, tt:438.590
# Ep:77, loss:0.00004, loss_test:0.04945, lr:4.61e-03, fs:0.93694 (r=0.963,p=0.912),  time:5.692, tt:444.004
# Ep:78, loss:0.00004, loss_test:0.05022, lr:4.57e-03, fs:0.92035 (r=0.963,p=0.881),  time:5.693, tt:449.780
# Ep:79, loss:0.00004, loss_test:0.04656, lr:4.52e-03, fs:0.95413 (r=0.963,p=0.945),  time:5.690, tt:455.221
# ##########Best model found so far##########
# Ep:80, loss:0.00004, loss_test:0.04742, lr:4.48e-03, fs:0.92035 (r=0.963,p=0.881),  time:5.688, tt:460.742
# Ep:81, loss:0.00004, loss_test:0.04584, lr:4.43e-03, fs:0.94545 (r=0.963,p=0.929),  time:5.690, tt:466.547
# Ep:82, loss:0.00004, loss_test:0.04638, lr:4.39e-03, fs:0.94545 (r=0.963,p=0.929),  time:5.689, tt:472.177
# Ep:83, loss:0.00004, loss_test:0.04899, lr:4.34e-03, fs:0.93578 (r=0.944,p=0.927),  time:5.687, tt:477.702
# Ep:84, loss:0.00004, loss_test:0.04551, lr:4.30e-03, fs:0.92035 (r=0.963,p=0.881),  time:5.691, tt:483.776
# Ep:85, loss:0.00004, loss_test:0.04448, lr:4.26e-03, fs:0.95413 (r=0.963,p=0.945),  time:5.699, tt:490.084
# Ep:86, loss:0.00003, loss_test:0.04509, lr:4.21e-03, fs:0.92857 (r=0.963,p=0.897),  time:5.704, tt:496.255
# Ep:87, loss:0.00003, loss_test:0.04328, lr:4.17e-03, fs:0.94545 (r=0.963,p=0.929),  time:5.708, tt:502.297
# Ep:88, loss:0.00004, loss_test:0.04353, lr:4.13e-03, fs:0.96296 (r=0.963,p=0.963),  time:5.712, tt:508.348
# ##########Best model found so far##########
# Ep:89, loss:0.00003, loss_test:0.04281, lr:4.09e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.720, tt:514.777
# ##########Best model found so far##########
# Ep:90, loss:0.00003, loss_test:0.04419, lr:4.05e-03, fs:0.96296 (r=0.963,p=0.963),  time:5.722, tt:520.673
# Ep:91, loss:0.00003, loss_test:0.04242, lr:4.01e-03, fs:0.96296 (r=0.963,p=0.963),  time:5.725, tt:526.698
# Ep:92, loss:0.00003, loss_test:0.04152, lr:3.97e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.732, tt:533.064
# Ep:93, loss:0.00003, loss_test:0.04081, lr:3.93e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.736, tt:539.194
# Ep:94, loss:0.00003, loss_test:0.04091, lr:3.89e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.730, tt:544.348
# Ep:95, loss:0.00003, loss_test:0.03968, lr:3.85e-03, fs:0.96296 (r=0.963,p=0.963),  time:5.727, tt:549.824
# Ep:96, loss:0.00003, loss_test:0.04042, lr:3.81e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.722, tt:555.020
# Ep:97, loss:0.00003, loss_test:0.03955, lr:3.77e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.717, tt:560.220
# Ep:98, loss:0.00002, loss_test:0.03974, lr:3.73e-03, fs:0.95413 (r=0.963,p=0.945),  time:5.711, tt:565.437
# Ep:99, loss:0.00002, loss_test:0.03825, lr:3.70e-03, fs:0.96296 (r=0.963,p=0.963),  time:5.706, tt:570.581
# Ep:100, loss:0.00002, loss_test:0.03856, lr:3.66e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.700, tt:575.738
# Ep:101, loss:0.00002, loss_test:0.03842, lr:3.62e-03, fs:0.96296 (r=0.963,p=0.963),  time:5.695, tt:580.894
# Ep:102, loss:0.00002, loss_test:0.03883, lr:3.59e-03, fs:0.96296 (r=0.963,p=0.963),  time:5.690, tt:586.071
# Ep:103, loss:0.00002, loss_test:0.03634, lr:3.55e-03, fs:0.96296 (r=0.963,p=0.963),  time:5.685, tt:591.283
# Ep:104, loss:0.00002, loss_test:0.03583, lr:3.52e-03, fs:0.96296 (r=0.963,p=0.963),  time:5.684, tt:596.846
# Ep:105, loss:0.00002, loss_test:0.03427, lr:3.48e-03, fs:0.96296 (r=0.963,p=0.963),  time:5.685, tt:602.573
# Ep:106, loss:0.00002, loss_test:0.03473, lr:3.45e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.677, tt:607.457
# Ep:107, loss:0.00002, loss_test:0.03458, lr:3.41e-03, fs:0.96296 (r=0.963,p=0.963),  time:5.669, tt:612.290
# Ep:108, loss:0.00002, loss_test:0.03204, lr:3.38e-03, fs:0.98113 (r=0.963,p=1.000),  time:5.662, tt:617.191
# ##########Best model found so far##########
# Ep:109, loss:0.00002, loss_test:0.03360, lr:3.34e-03, fs:0.96296 (r=0.963,p=0.963),  time:5.660, tt:622.631
# Ep:110, loss:0.00002, loss_test:0.03262, lr:3.31e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.655, tt:627.746
# Ep:111, loss:0.00002, loss_test:0.03022, lr:3.28e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.649, tt:632.637
# Ep:112, loss:0.00002, loss_test:0.03125, lr:3.24e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.645, tt:637.913
# Ep:113, loss:0.00002, loss_test:0.03207, lr:3.21e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.640, tt:642.936
# Ep:114, loss:0.00002, loss_test:0.03245, lr:3.18e-03, fs:0.95413 (r=0.963,p=0.945),  time:5.634, tt:647.895
# Ep:115, loss:0.00002, loss_test:0.03051, lr:3.15e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.632, tt:653.310
# Ep:116, loss:0.00001, loss_test:0.02855, lr:3.12e-03, fs:0.98113 (r=0.963,p=1.000),  time:5.628, tt:658.443
# Ep:117, loss:0.00001, loss_test:0.02988, lr:3.09e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.623, tt:663.530
# Ep:118, loss:0.00001, loss_test:0.03000, lr:3.05e-03, fs:0.97196 (r=0.963,p=0.981),  time:5.621, tt:668.855
# Ep:119, loss:0.00001, loss_test:0.02870, lr:3.02e-03, fs:0.96296 (r=0.963,p=0.963),  time:5.619, tt:674.238
# Model and results saved
# Saving best model...
# Model and results saved

# %% [markdown]
# ## Plot results <br>
#
# <p>This will plot charts of fscore/accuracy for all the results that match the parameters options under the /results folder</p>
#
# #### Parameters options
#
# <p> Choose one of each and pass it to the corresponding plot function in the following order:
#
# <b>1) neg_sample</b> = [1,2,3,4...etc] <br>
# <b>2) ds_name</b> = ["openml_203ds_datasets_matching"] <br>
# <b>3) experiment</b> = ["10_cv","random_subsam","hold_out"] <br>
# <b>4) archi</b> = ["Fasttext_150","Fasttext_300","Bert_300","Bert_768"] <br>
# <b>5) optimizer</b> = ["adam","sgd"] <br>
# <b>6) loss_functions</b> = ["ContrastiveLoss","CosineEmbeddingLoss"] <br>
#
# #### Types of chart
# <b>plot.plot_cv_details:</b> line charts of accuracy and fscore results for the several runs in cv_10 and random_subsampling<br>
# <b>plot.plot_bar </b>: bar charts of maximum results of accuracy and fscore for the several runs in cv_10 and random_subsampling <br>
# <b>plot.plot_details</b>: line charts of accuracy, fscore, recall and precision results for a hold_out run

# %%
##examples
##Line chart: plot hold_out results
# plot.plot_details(2,"monitor","hold_out","Fasttext2_364","sgd","CosineEmbeddingLoss",nit=["50"])
##Line chart: plot 10-fold-cv and random_subsampling results
# plot.plot_bar(2,"openML","random_subsam","Fasttext2_364","sgd","CosineEmbeddingLoss",nit=["120"])
##Bar chart: plot 10-fold-cv and random_subsampling results
# plot.plot_cv_details(2,"openML","random_subsam","Fasttext2_364","sgd","CosineEmbeddingLoss",nit=["120"])

# %%
plot.plot_bar(2,"openML","10_cv","Fasttext2_364","sgd","CosineEmbeddingLoss",nit=["120"])

# %%
plot.plot_cv_details(2,"openML","10_cv","Fasttext2_364","sgd","CosineEmbeddingLoss",nit=["120"])
