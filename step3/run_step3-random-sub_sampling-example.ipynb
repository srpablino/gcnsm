# %% [markdown]
# # Random sub-sampling run example

# %%
"""
Choose the dataset name for the ground_truth and graph embeddings (examples are: "monitor" and "openML")
"""
dataset_name = "openML"

"""
choose integer number of ratio negative/positive for the negative sampling (0 to 20)
"""
neg_sample = 2

"""
Choose experiment ["hold_out","random_subsam","10_cv"] : 
- hold_out will get the train/test split within ./ground_truth/dataset_name/hold_out
- random_subsam will isolate 1 node from some clusters of similar nodes in the ground truth. The isolated nodes will not be seen during training
- 10_cv: will split the ground truth in 10 folds, using each fold as test at least once. 
"""
strategy = "random_subsam"

"""
Choose to use the selected strategy to create a new split 
or reuse a previously created one (useful to repeat exact same experiment)
"""
create_new_split = True

print("Env variables set")

#import libraries
import step3_gcnsm
from step3_gcnsm import confusion_matrix as confusion_matrix
from step3_gcnsm import train as train
from step3_gcnsm import cross_validation as cross_validation
from step3_gcnsm import test_mask, train_mask
from step3_gcnsm import g
import step3_gcn_nn_concatenate as gcn_nn
import step3_gcn_loss as gcn_loss
import step3_gcn_training as gcn_training
import step3_plot_results as plot
step3_gcnsm.load_env(ds_name=dataset_name,ns=neg_sample,experiment=strategy,new_split=create_new_split)
print("\n SETUP IS READY")
# Out:
# Env variables set
# Using backend: pytorch
# Values to load
# dataset_name=openML
# neg_sample= 2
# strategy= random_subsam
# create_new_split= True
# cross_v= 0
# Creating cross validation splits...
# ITERATION: 0
# ITERATION: 1
# ITERATION: 2
# ITERATION: 3
# ITERATION: 4
# ITERATION: 5
# ITERATION: 6
# ITERATION: 7
# ITERATION: 8
# ITERATION: 9
# ITERATION: 10
# ITERATION: 11
# ITERATION: 12
# ITERATION: 13
# ITERATION: 14
# ITERATION: 15
# ITERATION: 16
# ITERATION: 17
# ITERATION: 18
# ITERATION: 19
# Train/Test split done
# Dataset splits loaded
# Train positive samples: 456 Test positive samples: 87
# Meta-feature graph from datasets loaded
#
#  SETUP IS READY

# %% [markdown]
# # Choose NN architecture and loss function, then run tests

# %% [markdown]
# ### Config and run training
# ### NN architectures:

# %%
##run this to see the different options of NN architectures
gcn_nn.get_options()
# Out:
# {0: 'Bert2_400',
#  1: 'Bert2_832',
#  2: 'Bert2_832_400_200_100',
#  3: 'Bert2_832_600_400_200',
#  4: 'Bert_300',
#  5: 'Bert_300_300_200',
#  6: 'Bert_768',
#  7: 'Fasttext2',
#  8: 'Fasttext2_150',
#  9: 'Fasttext2_200_200',
#  10: 'Fasttext2_200_200_100',
#  11: 'Fasttext2_200_200_200',
#  12: 'Fasttext2_200_200_200_100',
#  13: 'Fasttext2_200_200_200_100_relu',
#  14: 'Fasttext2_300_250_200_150',
#  15: 'Fasttext2_364',
#  16: 'Fasttext2_364_200_100',
#  17: 'Fasttext2_364_200_100_relu',
#  18: 'Fasttext2_364_300_200_100',
#  19: 'Fasttext2_364_300_200_100_relu',
#  20: 'Fasttext2_364_300_250_200',
#  21: 'Fasttext2_364_364_364',
#  22: 'Fasttext2_364_nn',
#  23: 'Fasttext2_3GCN_300_250_200_150',
#  24: 'Fasttext2_728',
#  25: 'Fasttext2_728364',
#  26: 'Fasttext2_728_364',
#  27: 'Fasttext2d_300_250_200_150',
#  28: 'Fasttext2d_364',
#  29: 'Fasttext2d_364_364_364',
#  30: 'Fasttext2d_728_364',
#  31: 'Fasttext3GCN_300',
#  32: 'FasttextSum_150',
#  33: 'FasttextSum_300_250_200_150',
#  34: 'FasttextSum_364',
#  35: 'FasttextSum_364_200_100',
#  36: 'FasttextSum_364_300_200_100',
#  37: 'FasttextSumd_150',
#  38: 'FasttextSumd_300_250_200_150',
#  39: 'Fasttext_150',
#  40: 'Fasttext_150_150_100',
#  41: 'Fasttext_200_200_200_100',
#  42: 'Fasttext_300',
#  43: 'Fasttext_300_200_100',
#  44: 'Fasttext_300_250_200_150',
#  45: 'Fasttext_300_300_300',
#  46: 'Fasttext_3GCN',
#  47: 'Fasttext_600_300',
#  48: 'Fasttext_simple_300_300'}

# %% [markdown]
# ### Loss functions:
# {<br>
#     "0": "ContrastiveLoss", <br>
#     "1": "CosineEmbeddingLoss", <br>
# }
#
# ### Optimizer
# {<br>
#     "adam" (default)<br>
#     "sgd"<br>
# }
#
#
# ### Loss functions parameters examples: format -> [margin]+[aggregation_function]
# {<br>
#     0.9+mean, <br>
#     0.7+mean, <br>
#     0.5+mean, <br>
#     0.3+mean, <br>
#     0.9+sum, <br>
#     0.7+sum, <br>
#     0.5+sum, <br>
#     0.3+sum, <br>
# }
#
# ### batch_splits examples:
# {<br>
#     1024, <br>
#     2048, <br>
# }
# ### learning rate examples (lr):
# {<br>
#     6e-3, <br>
#     1e-2, <br>
# }

# %% [markdown]
# ### Random sub-sampling run example

# %%
#train new model and specify parameters
training_object = gcn_training.Training()
training_object.set_training(
            net_name= "Fasttext2_364",  #_of_option for NN architecture
            batch_splits=1024 ,#_of_sets(this will (give dataset / batch_splits) size of batch
            lr=1e-2 , #learning rate for training (e.g. 1e-3 )
            loss_name=gcn_loss.get_option_name(1), #_of_option for loss 
            loss_parameters="0.5+mean" ,#loss function parameters separated by '+' e.g. for cosine and contrastive "0.0+mean"
            optimizer_name="sgd" ) #adam or sgd, default adam

cross_validation(training_object,120,"1-20",nsample=2)
# Out:
# Values to load
# dataset_name=openML
# neg_sample= 0
# strategy= random_subsam
# create_new_split= False
# cross_v= 0
# Dataset splits loaded
# Train positive samples: 456 Test positive samples: 87
# Meta-feature graph from datasets loaded
# Start of training...NN Fasttext2_364 Loss CosineEmbeddingLoss Split 1024:
# Ep:0, loss:0.00062, loss_test:0.24383, lr:1.00e-02, fs:0.66667 (r=1.000,p=0.500),  time:4.804, tt:4.804
# ##########Best model found so far##########
# Ep:1, loss:0.00062, loss_test:0.24224, lr:9.90e-03, fs:0.66667 (r=1.000,p=0.500),  time:4.765, tt:9.530
# Ep:2, loss:0.00061, loss_test:0.23904, lr:9.80e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.152, tt:15.455
# Ep:3, loss:0.00059, loss_test:0.23291, lr:9.70e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.613, tt:22.453
# Ep:4, loss:0.00055, loss_test:0.22094, lr:9.61e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.733, tt:28.663
# Ep:5, loss:0.00048, loss_test:0.20536, lr:9.51e-03, fs:0.66406 (r=0.977,p=0.503),  time:5.576, tt:33.459
# Ep:6, loss:0.00040, loss_test:0.19818, lr:9.41e-03, fs:0.70175 (r=0.920,p=0.567),  time:5.462, tt:38.235
# ##########Best model found so far##########
# Ep:7, loss:0.00033, loss_test:0.20161, lr:9.32e-03, fs:0.71220 (r=0.839,p=0.619),  time:5.379, tt:43.033
# ##########Best model found so far##########
# Ep:8, loss:0.00032, loss_test:0.20202, lr:9.23e-03, fs:0.68687 (r=0.782,p=0.613),  time:5.475, tt:49.278
# Ep:9, loss:0.00031, loss_test:0.20389, lr:9.14e-03, fs:0.68783 (r=0.747,p=0.637),  time:5.522, tt:55.217
# Ep:10, loss:0.00029, loss_test:0.20080, lr:9.04e-03, fs:0.69892 (r=0.747,p=0.657),  time:5.570, tt:61.274
# Ep:11, loss:0.00028, loss_test:0.19832, lr:8.95e-03, fs:0.67347 (r=0.759,p=0.606),  time:5.595, tt:67.136
# Ep:12, loss:0.00028, loss_test:0.18766, lr:8.86e-03, fs:0.71066 (r=0.805,p=0.636),  time:5.620, tt:73.054
# Ep:13, loss:0.00027, loss_test:0.18560, lr:8.78e-03, fs:0.73016 (r=0.793,p=0.676),  time:5.649, tt:79.084
# ##########Best model found so far##########
# Ep:14, loss:0.00025, loss_test:0.18508, lr:8.69e-03, fs:0.70408 (r=0.793,p=0.633),  time:5.742, tt:86.124
# Ep:15, loss:0.00025, loss_test:0.18052, lr:8.60e-03, fs:0.72432 (r=0.770,p=0.684),  time:5.753, tt:92.045
# Ep:16, loss:0.00025, loss_test:0.17369, lr:8.51e-03, fs:0.77249 (r=0.839,p=0.716),  time:5.775, tt:98.183
# ##########Best model found so far##########
# Ep:17, loss:0.00023, loss_test:0.17057, lr:8.43e-03, fs:0.76757 (r=0.816,p=0.724),  time:5.795, tt:104.311
# Ep:18, loss:0.00023, loss_test:0.16809, lr:8.35e-03, fs:0.77596 (r=0.816,p=0.740),  time:5.801, tt:110.220
# ##########Best model found so far##########
# Ep:19, loss:0.00023, loss_test:0.16999, lr:8.26e-03, fs:0.78212 (r=0.805,p=0.761),  time:5.805, tt:116.098
# ##########Best model found so far##########
# Ep:20, loss:0.00021, loss_test:0.16256, lr:8.18e-03, fs:0.78947 (r=0.862,p=0.728),  time:5.805, tt:121.904
# ##########Best model found so far##########
# Ep:21, loss:0.00021, loss_test:0.15946, lr:8.10e-03, fs:0.79781 (r=0.839,p=0.760),  time:5.799, tt:127.578
# ##########Best model found so far##########
# Ep:22, loss:0.00020, loss_test:0.15732, lr:8.02e-03, fs:0.82979 (r=0.897,p=0.772),  time:5.817, tt:133.780
# ##########Best model found so far##########
# Ep:23, loss:0.00020, loss_test:0.15756, lr:7.94e-03, fs:0.78212 (r=0.805,p=0.761),  time:5.816, tt:139.579
# Ep:24, loss:0.00019, loss_test:0.15271, lr:7.86e-03, fs:0.81720 (r=0.874,p=0.768),  time:5.964, tt:149.095
# Ep:25, loss:0.00018, loss_test:0.14459, lr:7.78e-03, fs:0.83770 (r=0.920,p=0.769),  time:6.079, tt:158.047
# ##########Best model found so far##########
# Ep:26, loss:0.00018, loss_test:0.14308, lr:7.70e-03, fs:0.86010 (r=0.954,p=0.783),  time:6.103, tt:164.786
# ##########Best model found so far##########
# Ep:27, loss:0.00017, loss_test:0.14146, lr:7.62e-03, fs:0.87047 (r=0.966,p=0.792),  time:6.087, tt:170.444
# ##########Best model found so far##########
# Ep:28, loss:0.00017, loss_test:0.14140, lr:7.55e-03, fs:0.85427 (r=0.977,p=0.759),  time:6.085, tt:176.475
# Ep:29, loss:0.00016, loss_test:0.13764, lr:7.47e-03, fs:0.86772 (r=0.943,p=0.804),  time:6.083, tt:182.486
# Ep:30, loss:0.00015, loss_test:0.13010, lr:7.40e-03, fs:0.87310 (r=0.989,p=0.782),  time:6.091, tt:188.830
# ##########Best model found so far##########
# Ep:31, loss:0.00015, loss_test:0.13261, lr:7.32e-03, fs:0.87958 (r=0.966,p=0.808),  time:6.075, tt:194.390
# ##########Best model found so far##########
# Ep:32, loss:0.00015, loss_test:0.12764, lr:7.25e-03, fs:0.88205 (r=0.989,p=0.796),  time:6.080, tt:200.656
# ##########Best model found so far##########
# Ep:33, loss:0.00014, loss_test:0.12735, lr:7.18e-03, fs:0.88083 (r=0.977,p=0.802),  time:6.080, tt:206.709
# Ep:34, loss:0.00014, loss_test:0.12958, lr:7.11e-03, fs:0.88205 (r=0.989,p=0.796),  time:6.077, tt:212.686
# Ep:35, loss:0.00013, loss_test:0.12091, lr:7.03e-03, fs:0.88205 (r=0.989,p=0.796),  time:6.094, tt:219.374
# Ep:36, loss:0.00013, loss_test:0.12184, lr:6.96e-03, fs:0.91979 (r=0.989,p=0.860),  time:6.077, tt:224.841
# ##########Best model found so far##########
# Ep:37, loss:0.00013, loss_test:0.12154, lr:6.89e-03, fs:0.90526 (r=0.989,p=0.835),  time:6.074, tt:230.808
# Ep:38, loss:0.00013, loss_test:0.11409, lr:6.83e-03, fs:0.89691 (r=1.000,p=0.813),  time:6.072, tt:236.819
# Ep:39, loss:0.00012, loss_test:0.11696, lr:6.76e-03, fs:0.91489 (r=0.989,p=0.851),  time:6.083, tt:243.337
# Ep:40, loss:0.00012, loss_test:0.11672, lr:6.69e-03, fs:0.90052 (r=0.989,p=0.827),  time:6.077, tt:249.157
# Ep:41, loss:0.00011, loss_test:0.11120, lr:6.62e-03, fs:0.90155 (r=1.000,p=0.821),  time:6.075, tt:255.170
# Ep:42, loss:0.00011, loss_test:0.11990, lr:6.56e-03, fs:0.90217 (r=0.954,p=0.856),  time:6.073, tt:261.142
# Ep:43, loss:0.00010, loss_test:0.11457, lr:6.49e-03, fs:0.91099 (r=1.000,p=0.837),  time:6.075, tt:267.295
# Ep:44, loss:0.00011, loss_test:0.11076, lr:6.43e-03, fs:0.92063 (r=1.000,p=0.853),  time:6.071, tt:273.213
# ##########Best model found so far##########
# Ep:45, loss:0.00010, loss_test:0.11248, lr:6.36e-03, fs:0.92473 (r=0.989,p=0.869),  time:6.138, tt:282.349
# ##########Best model found so far##########
# Ep:46, loss:0.00010, loss_test:0.11119, lr:6.30e-03, fs:0.92473 (r=0.989,p=0.869),  time:6.205, tt:291.646
# Ep:47, loss:0.00009, loss_test:0.10582, lr:6.24e-03, fs:0.91099 (r=1.000,p=0.837),  time:6.268, tt:300.886
# Ep:48, loss:0.00009, loss_test:0.11168, lr:6.17e-03, fs:0.92063 (r=1.000,p=0.853),  time:6.259, tt:306.693
# Ep:49, loss:0.00009, loss_test:0.10831, lr:6.11e-03, fs:0.91099 (r=1.000,p=0.837),  time:6.256, tt:312.803
# Ep:50, loss:0.00009, loss_test:0.10519, lr:6.05e-03, fs:0.91579 (r=1.000,p=0.845),  time:6.259, tt:319.202
# Ep:51, loss:0.00009, loss_test:0.11495, lr:5.99e-03, fs:0.89617 (r=0.943,p=0.854),  time:6.255, tt:325.281
# Ep:52, loss:0.00008, loss_test:0.10614, lr:5.93e-03, fs:0.92553 (r=1.000,p=0.861),  time:6.246, tt:331.019
# ##########Best model found so far##########
# Ep:53, loss:0.00008, loss_test:0.09995, lr:5.87e-03, fs:0.93048 (r=1.000,p=0.870),  time:6.248, tt:337.404
# ##########Best model found so far##########
# Ep:54, loss:0.00008, loss_test:0.11427, lr:5.81e-03, fs:0.88136 (r=0.897,p=0.867),  time:6.245, tt:343.476
# Ep:55, loss:0.00008, loss_test:0.10994, lr:5.75e-03, fs:0.89617 (r=0.943,p=0.854),  time:6.241, tt:349.517
# Ep:56, loss:0.00007, loss_test:0.10002, lr:5.70e-03, fs:0.92063 (r=1.000,p=0.853),  time:6.234, tt:355.354
# Ep:57, loss:0.00007, loss_test:0.10847, lr:5.64e-03, fs:0.93923 (r=0.977,p=0.904),  time:6.228, tt:361.213
# ##########Best model found so far##########
# Ep:58, loss:0.00007, loss_test:0.10317, lr:5.58e-03, fs:0.93548 (r=1.000,p=0.879),  time:6.220, tt:366.967
# Ep:59, loss:0.00007, loss_test:0.10087, lr:5.53e-03, fs:0.93048 (r=1.000,p=0.870),  time:6.218, tt:373.077
# Ep:60, loss:0.00006, loss_test:0.10218, lr:5.47e-03, fs:0.94054 (r=1.000,p=0.888),  time:6.207, tt:378.637
# ##########Best model found so far##########
# Ep:61, loss:0.00006, loss_test:0.10135, lr:5.42e-03, fs:0.92973 (r=0.989,p=0.878),  time:6.196, tt:384.141
# Ep:62, loss:0.00006, loss_test:0.10230, lr:5.36e-03, fs:0.92473 (r=0.989,p=0.869),  time:6.187, tt:389.803
# Ep:63, loss:0.00006, loss_test:0.10367, lr:5.31e-03, fs:0.93989 (r=0.989,p=0.896),  time:6.177, tt:395.353
# Ep:64, loss:0.00006, loss_test:0.10078, lr:5.26e-03, fs:0.94054 (r=1.000,p=0.888),  time:6.164, tt:400.644
# Ep:65, loss:0.00006, loss_test:0.10198, lr:5.20e-03, fs:0.92973 (r=0.989,p=0.878),  time:6.151, tt:405.940
# Ep:66, loss:0.00005, loss_test:0.10309, lr:5.15e-03, fs:0.93407 (r=0.977,p=0.895),  time:6.161, tt:412.818
# Ep:67, loss:0.00005, loss_test:0.10563, lr:5.10e-03, fs:0.92655 (r=0.943,p=0.911),  time:6.188, tt:420.772
# Ep:68, loss:0.00005, loss_test:0.10440, lr:5.05e-03, fs:0.93258 (r=0.954,p=0.912),  time:6.217, tt:428.969
# Ep:69, loss:0.00005, loss_test:0.10409, lr:5.00e-03, fs:0.92655 (r=0.943,p=0.911),  time:6.212, tt:434.845
# Ep:70, loss:0.00005, loss_test:0.09824, lr:4.95e-03, fs:0.93478 (r=0.989,p=0.887),  time:6.203, tt:440.427
# Ep:71, loss:0.00005, loss_test:0.10787, lr:4.90e-03, fs:0.87861 (r=0.874,p=0.884),  time:6.192, tt:445.812
# Ep:72, loss:0.00005, loss_test:0.10101, lr:4.85e-03, fs:0.93923 (r=0.977,p=0.904),  time:6.189, tt:451.812
# Ep:73, loss:0.00004, loss_test:0.10073, lr:4.80e-03, fs:0.93923 (r=0.977,p=0.904),  time:6.189, tt:457.950
# Ep:74, loss:0.00004, loss_test:0.10980, lr:4.75e-03, fs:0.88235 (r=0.862,p=0.904),  time:6.184, tt:463.802
# Ep:75, loss:0.00004, loss_test:0.10522, lr:4.71e-03, fs:0.91429 (r=0.920,p=0.909),  time:6.185, tt:470.067
# Ep:76, loss:0.00004, loss_test:0.10552, lr:4.66e-03, fs:0.89143 (r=0.897,p=0.886),  time:6.181, tt:475.931
# Ep:77, loss:0.00004, loss_test:0.10777, lr:4.61e-03, fs:0.89535 (r=0.885,p=0.906),  time:6.180, tt:482.039
# Ep:78, loss:0.00004, loss_test:0.10818, lr:4.57e-03, fs:0.88235 (r=0.862,p=0.904),  time:6.175, tt:487.845
# Ep:79, loss:0.00004, loss_test:0.10892, lr:4.52e-03, fs:0.88235 (r=0.862,p=0.904),  time:6.176, tt:494.068
# Ep:80, loss:0.00004, loss_test:0.11111, lr:4.48e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.176, tt:500.262
# Ep:81, loss:0.00004, loss_test:0.10668, lr:4.43e-03, fs:0.89286 (r=0.862,p=0.926),  time:6.172, tt:506.106
# Ep:82, loss:0.00003, loss_test:0.10628, lr:4.39e-03, fs:0.89941 (r=0.874,p=0.927),  time:6.167, tt:511.886
# Ep:83, loss:0.00003, loss_test:0.11173, lr:4.34e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.164, tt:517.752
# Ep:84, loss:0.00003, loss_test:0.10962, lr:4.30e-03, fs:0.87719 (r=0.862,p=0.893),  time:6.158, tt:523.441
# Ep:85, loss:0.00003, loss_test:0.11086, lr:4.26e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.156, tt:529.441
# Ep:86, loss:0.00003, loss_test:0.11544, lr:4.21e-03, fs:0.89286 (r=0.862,p=0.926),  time:6.154, tt:535.413
# Ep:87, loss:0.00003, loss_test:0.11445, lr:4.17e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.157, tt:541.836
# Ep:88, loss:0.00003, loss_test:0.11073, lr:4.13e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.188, tt:550.766
# Ep:89, loss:0.00003, loss_test:0.11036, lr:4.09e-03, fs:0.88095 (r=0.851,p=0.914),  time:6.220, tt:559.772
# Ep:90, loss:0.00003, loss_test:0.11615, lr:4.05e-03, fs:0.88235 (r=0.862,p=0.904),  time:6.238, tt:567.614
# Ep:91, loss:0.00003, loss_test:0.10925, lr:4.01e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.236, tt:573.705
# Ep:92, loss:0.00003, loss_test:0.11553, lr:3.97e-03, fs:0.88235 (r=0.862,p=0.904),  time:6.234, tt:579.776
# Ep:93, loss:0.00003, loss_test:0.11874, lr:3.93e-03, fs:0.90361 (r=0.862,p=0.949),  time:6.231, tt:585.694
# Ep:94, loss:0.00003, loss_test:0.11141, lr:3.89e-03, fs:0.87273 (r=0.828,p=0.923),  time:6.228, tt:591.644
# Ep:95, loss:0.00003, loss_test:0.10988, lr:3.85e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.224, tt:597.530
# Ep:96, loss:0.00002, loss_test:0.11721, lr:3.81e-03, fs:0.88235 (r=0.862,p=0.904),  time:6.223, tt:603.625
# Ep:97, loss:0.00003, loss_test:0.11407, lr:3.77e-03, fs:0.89286 (r=0.862,p=0.926),  time:6.226, tt:610.140
# Ep:98, loss:0.00003, loss_test:0.11234, lr:3.73e-03, fs:0.86585 (r=0.816,p=0.922),  time:6.224, tt:616.165
# Ep:99, loss:0.00002, loss_test:0.12578, lr:3.70e-03, fs:0.89157 (r=0.851,p=0.937),  time:6.222, tt:622.241
# Ep:100, loss:0.00002, loss_test:0.12512, lr:3.66e-03, fs:0.89820 (r=0.862,p=0.938),  time:6.221, tt:628.278
# Ep:101, loss:0.00002, loss_test:0.11834, lr:3.62e-03, fs:0.89820 (r=0.862,p=0.938),  time:6.218, tt:634.237
# Ep:102, loss:0.00002, loss_test:0.11716, lr:3.59e-03, fs:0.89286 (r=0.862,p=0.926),  time:6.219, tt:640.552
# Ep:103, loss:0.00002, loss_test:0.11537, lr:3.55e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.218, tt:646.643
# Ep:104, loss:0.00002, loss_test:0.11528, lr:3.52e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.218, tt:652.869
# Ep:105, loss:0.00002, loss_test:0.12153, lr:3.48e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.216, tt:658.880
# Ep:106, loss:0.00002, loss_test:0.11958, lr:3.45e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.214, tt:664.941
# Ep:107, loss:0.00002, loss_test:0.12095, lr:3.41e-03, fs:0.88095 (r=0.851,p=0.914),  time:6.211, tt:670.813
# Ep:108, loss:0.00002, loss_test:0.12095, lr:3.38e-03, fs:0.86585 (r=0.816,p=0.922),  time:6.211, tt:676.953
# Ep:109, loss:0.00002, loss_test:0.11997, lr:3.34e-03, fs:0.89820 (r=0.862,p=0.938),  time:6.212, tt:683.318
# Ep:110, loss:0.00002, loss_test:0.11623, lr:3.31e-03, fs:0.85890 (r=0.805,p=0.921),  time:6.237, tt:692.357
# Ep:111, loss:0.00002, loss_test:0.12100, lr:3.28e-03, fs:0.84472 (r=0.782,p=0.919),  time:6.266, tt:701.817
# Ep:112, loss:0.00002, loss_test:0.12397, lr:3.24e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.265, tt:707.986
# Ep:113, loss:0.00002, loss_test:0.11994, lr:3.21e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.263, tt:713.952
# Ep:114, loss:0.00002, loss_test:0.11989, lr:3.18e-03, fs:0.85185 (r=0.793,p=0.920),  time:6.260, tt:719.845
# Ep:115, loss:0.00002, loss_test:0.12670, lr:3.15e-03, fs:0.85366 (r=0.805,p=0.909),  time:6.257, tt:725.784
# Ep:116, loss:0.00002, loss_test:0.13137, lr:3.12e-03, fs:0.86747 (r=0.828,p=0.911),  time:6.254, tt:731.768
# Ep:117, loss:0.00002, loss_test:0.12475, lr:3.09e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.253, tt:737.871
# Ep:118, loss:0.00002, loss_test:0.12397, lr:3.05e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.251, tt:743.890
# Ep:119, loss:0.00001, loss_test:0.12462, lr:3.02e-03, fs:0.88757 (r=0.862,p=0.915),  time:6.248, tt:749.734
# Model and results saved
# Saving best model...
# Model and results saved
# Values to load
# dataset_name=openML
# neg_sample= 0
# strategy= random_subsam
# create_new_split= False
# cross_v= 1
# Dataset splits loaded
# Train positive samples: 456 Test positive samples: 87
# Meta-feature graph from datasets loaded
# Start of training...NN Fasttext2_364 Loss CosineEmbeddingLoss Split 1024:
# Ep:0, loss:0.00062, loss_test:0.24581, lr:1.00e-02, fs:0.66667 (r=1.000,p=0.500),  time:6.038, tt:6.038
# ##########Best model found so far##########
# Ep:1, loss:0.00062, loss_test:0.24466, lr:9.90e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.880, tt:11.760
# Ep:2, loss:0.00060, loss_test:0.24241, lr:9.80e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.661, tt:16.983
# Ep:3, loss:0.00059, loss_test:0.23793, lr:9.70e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.842, tt:23.369
# Ep:4, loss:0.00055, loss_test:0.22941, lr:9.61e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.935, tt:29.677
# Ep:5, loss:0.00048, loss_test:0.21711, lr:9.51e-03, fs:0.65625 (r=0.966,p=0.497),  time:5.746, tt:34.478
# Ep:6, loss:0.00040, loss_test:0.20371, lr:9.41e-03, fs:0.68050 (r=0.943,p=0.532),  time:5.603, tt:39.222
# ##########Best model found so far##########
# Ep:7, loss:0.00033, loss_test:0.20514, lr:9.32e-03, fs:0.70370 (r=0.874,p=0.589),  time:5.460, tt:43.676
# ##########Best model found so far##########
# Ep:8, loss:0.00031, loss_test:0.21165, lr:9.23e-03, fs:0.68519 (r=0.851,p=0.574),  time:5.334, tt:48.009
# Ep:9, loss:0.00029, loss_test:0.21538, lr:9.14e-03, fs:0.68932 (r=0.816,p=0.597),  time:5.700, tt:57.002
# Ep:10, loss:0.00029, loss_test:0.21454, lr:9.04e-03, fs:0.68020 (r=0.770,p=0.609),  time:6.029, tt:66.322
# Ep:11, loss:0.00028, loss_test:0.21648, lr:8.95e-03, fs:0.66990 (r=0.793,p=0.580),  time:6.190, tt:74.285
# Ep:12, loss:0.00027, loss_test:0.21977, lr:8.86e-03, fs:0.64948 (r=0.724,p=0.589),  time:6.151, tt:79.962
# Ep:13, loss:0.00026, loss_test:0.21055, lr:8.78e-03, fs:0.69036 (r=0.782,p=0.618),  time:6.139, tt:85.950
# Ep:14, loss:0.00025, loss_test:0.20969, lr:8.69e-03, fs:0.68687 (r=0.782,p=0.613),  time:6.151, tt:92.269
# Ep:15, loss:0.00024, loss_test:0.20889, lr:8.60e-03, fs:0.66667 (r=0.759,p=0.595),  time:6.149, tt:98.377
# Ep:16, loss:0.00024, loss_test:0.20174, lr:8.51e-03, fs:0.72727 (r=0.828,p=0.649),  time:6.106, tt:103.806
# ##########Best model found so far##########
# Ep:17, loss:0.00023, loss_test:0.19313, lr:8.43e-03, fs:0.76142 (r=0.862,p=0.682),  time:6.093, tt:109.671
# ##########Best model found so far##########
# Ep:18, loss:0.00022, loss_test:0.19098, lr:8.35e-03, fs:0.72195 (r=0.851,p=0.627),  time:6.081, tt:115.534
# Ep:19, loss:0.00021, loss_test:0.19709, lr:8.26e-03, fs:0.68657 (r=0.793,p=0.605),  time:6.061, tt:121.226
# Ep:20, loss:0.00021, loss_test:0.18966, lr:8.18e-03, fs:0.72165 (r=0.805,p=0.654),  time:6.039, tt:126.828
# Ep:21, loss:0.00020, loss_test:0.19248, lr:8.10e-03, fs:0.69189 (r=0.736,p=0.653),  time:6.012, tt:132.258
# Ep:22, loss:0.00019, loss_test:0.18997, lr:8.02e-03, fs:0.73684 (r=0.805,p=0.680),  time:5.987, tt:137.702
# Ep:23, loss:0.00019, loss_test:0.18214, lr:7.94e-03, fs:0.70936 (r=0.828,p=0.621),  time:5.957, tt:142.958
# Ep:24, loss:0.00019, loss_test:0.19035, lr:7.86e-03, fs:0.69945 (r=0.736,p=0.667),  time:5.962, tt:149.061
# Ep:25, loss:0.00017, loss_test:0.18560, lr:7.78e-03, fs:0.76923 (r=0.862,p=0.694),  time:5.932, tt:154.225
# ##########Best model found so far##########
# Ep:26, loss:0.00017, loss_test:0.18076, lr:7.70e-03, fs:0.74510 (r=0.874,p=0.650),  time:5.900, tt:159.301
# Ep:27, loss:0.00017, loss_test:0.17203, lr:7.62e-03, fs:0.80000 (r=0.897,p=0.722),  time:5.891, tt:164.950
# ##########Best model found so far##########
# Ep:28, loss:0.00016, loss_test:0.17808, lr:7.55e-03, fs:0.80208 (r=0.885,p=0.733),  time:5.875, tt:170.365
# ##########Best model found so far##########
# Ep:29, loss:0.00016, loss_test:0.17263, lr:7.47e-03, fs:0.78000 (r=0.897,p=0.690),  time:5.882, tt:176.469
# Ep:30, loss:0.00015, loss_test:0.16527, lr:7.40e-03, fs:0.80402 (r=0.920,p=0.714),  time:5.898, tt:182.838
# ##########Best model found so far##########
# Ep:31, loss:0.00015, loss_test:0.16869, lr:7.32e-03, fs:0.80000 (r=0.897,p=0.722),  time:5.969, tt:191.018
# Ep:32, loss:0.00015, loss_test:0.17055, lr:7.25e-03, fs:0.79592 (r=0.897,p=0.716),  time:6.057, tt:199.869
# Ep:33, loss:0.00014, loss_test:0.15885, lr:7.18e-03, fs:0.81218 (r=0.920,p=0.727),  time:6.059, tt:205.990
# ##########Best model found so far##########
# Ep:34, loss:0.00014, loss_test:0.16740, lr:7.11e-03, fs:0.79381 (r=0.885,p=0.720),  time:6.033, tt:211.139
# Ep:35, loss:0.00013, loss_test:0.15355, lr:7.03e-03, fs:0.80612 (r=0.908,p=0.725),  time:6.023, tt:216.820
# Ep:36, loss:0.00013, loss_test:0.16249, lr:6.96e-03, fs:0.81026 (r=0.908,p=0.731),  time:6.018, tt:222.665
# Ep:37, loss:0.00012, loss_test:0.16213, lr:6.89e-03, fs:0.82723 (r=0.908,p=0.760),  time:6.016, tt:228.619
# ##########Best model found so far##########
# Ep:38, loss:0.00012, loss_test:0.15050, lr:6.83e-03, fs:0.82902 (r=0.920,p=0.755),  time:6.034, tt:235.321
# ##########Best model found so far##########
# Ep:39, loss:0.00012, loss_test:0.15879, lr:6.76e-03, fs:0.81865 (r=0.908,p=0.745),  time:6.016, tt:240.621
# Ep:40, loss:0.00012, loss_test:0.15474, lr:6.69e-03, fs:0.84043 (r=0.908,p=0.782),  time:5.992, tt:245.670
# ##########Best model found so far##########
# Ep:41, loss:0.00011, loss_test:0.14934, lr:6.62e-03, fs:0.83770 (r=0.920,p=0.769),  time:5.990, tt:251.571
# Ep:42, loss:0.00011, loss_test:0.14791, lr:6.56e-03, fs:0.82902 (r=0.920,p=0.755),  time:5.978, tt:257.033
# Ep:43, loss:0.00010, loss_test:0.14999, lr:6.49e-03, fs:0.82474 (r=0.920,p=0.748),  time:5.969, tt:262.621
# Ep:44, loss:0.00010, loss_test:0.15056, lr:6.43e-03, fs:0.84946 (r=0.908,p=0.798),  time:5.970, tt:268.634
# ##########Best model found so far##########
# Ep:45, loss:0.00010, loss_test:0.15223, lr:6.36e-03, fs:0.82902 (r=0.920,p=0.755),  time:5.959, tt:274.110
# Ep:46, loss:0.00010, loss_test:0.13928, lr:6.30e-03, fs:0.83770 (r=0.920,p=0.769),  time:5.945, tt:279.414
# Ep:47, loss:0.00010, loss_test:0.14842, lr:6.24e-03, fs:0.81443 (r=0.908,p=0.738),  time:5.945, tt:285.378
# Ep:48, loss:0.00010, loss_test:0.14581, lr:6.17e-03, fs:0.85106 (r=0.920,p=0.792),  time:5.943, tt:291.223
# ##########Best model found so far##########
# Ep:49, loss:0.00009, loss_test:0.14529, lr:6.11e-03, fs:0.83770 (r=0.920,p=0.769),  time:5.945, tt:297.244
# Ep:50, loss:0.00010, loss_test:0.14917, lr:6.05e-03, fs:0.85870 (r=0.908,p=0.814),  time:5.960, tt:303.941
# ##########Best model found so far##########
# Ep:51, loss:0.00009, loss_test:0.15060, lr:5.99e-03, fs:0.86486 (r=0.920,p=0.816),  time:5.950, tt:309.388
# ##########Best model found so far##########
# Ep:52, loss:0.00009, loss_test:0.14441, lr:5.93e-03, fs:0.86957 (r=0.920,p=0.825),  time:5.966, tt:316.208
# ##########Best model found so far##########
# Ep:53, loss:0.00008, loss_test:0.14745, lr:5.87e-03, fs:0.84946 (r=0.908,p=0.798),  time:6.023, tt:325.229
# Ep:54, loss:0.00009, loss_test:0.14141, lr:5.81e-03, fs:0.88398 (r=0.920,p=0.851),  time:6.074, tt:334.044
# ##########Best model found so far##########
# Ep:55, loss:0.00008, loss_test:0.14777, lr:5.75e-03, fs:0.86022 (r=0.920,p=0.808),  time:6.064, tt:339.599
# Ep:56, loss:0.00008, loss_test:0.13960, lr:5.70e-03, fs:0.85561 (r=0.920,p=0.800),  time:6.062, tt:345.555
# Ep:57, loss:0.00008, loss_test:0.14010, lr:5.64e-03, fs:0.88398 (r=0.920,p=0.851),  time:6.063, tt:351.671
# Ep:58, loss:0.00008, loss_test:0.14524, lr:5.58e-03, fs:0.87432 (r=0.920,p=0.833),  time:6.066, tt:357.870
# Ep:59, loss:0.00007, loss_test:0.14086, lr:5.53e-03, fs:0.85561 (r=0.920,p=0.800),  time:6.064, tt:363.860
# Ep:60, loss:0.00007, loss_test:0.13825, lr:5.47e-03, fs:0.87432 (r=0.920,p=0.833),  time:6.071, tt:370.360
# Ep:61, loss:0.00007, loss_test:0.13958, lr:5.42e-03, fs:0.88398 (r=0.920,p=0.851),  time:6.073, tt:376.515
# Ep:62, loss:0.00007, loss_test:0.14631, lr:5.36e-03, fs:0.85714 (r=0.862,p=0.852),  time:6.066, tt:382.149
# Ep:63, loss:0.00007, loss_test:0.14657, lr:5.31e-03, fs:0.88764 (r=0.908,p=0.868),  time:6.066, tt:388.249
# ##########Best model found so far##########
# Ep:64, loss:0.00007, loss_test:0.14515, lr:5.26e-03, fs:0.89773 (r=0.908,p=0.888),  time:6.063, tt:394.099
# ##########Best model found so far##########
# Ep:65, loss:0.00006, loss_test:0.13967, lr:5.20e-03, fs:0.89266 (r=0.908,p=0.878),  time:6.058, tt:399.859
# Ep:66, loss:0.00006, loss_test:0.14495, lr:5.15e-03, fs:0.87432 (r=0.920,p=0.833),  time:6.054, tt:405.650
# Ep:67, loss:0.00006, loss_test:0.14513, lr:5.10e-03, fs:0.86705 (r=0.862,p=0.872),  time:6.053, tt:411.600
# Ep:68, loss:0.00006, loss_test:0.14588, lr:5.05e-03, fs:0.87209 (r=0.862,p=0.882),  time:6.051, tt:417.520
# Ep:69, loss:0.00006, loss_test:0.14600, lr:5.00e-03, fs:0.87912 (r=0.920,p=0.842),  time:6.049, tt:423.406
# Ep:70, loss:0.00006, loss_test:0.13974, lr:4.95e-03, fs:0.88136 (r=0.897,p=0.867),  time:6.046, tt:429.294
# Ep:71, loss:0.00006, loss_test:0.15175, lr:4.90e-03, fs:0.87719 (r=0.862,p=0.893),  time:6.047, tt:435.374
# Ep:72, loss:0.00006, loss_test:0.14636, lr:4.85e-03, fs:0.88506 (r=0.885,p=0.885),  time:6.041, tt:440.978
# Ep:73, loss:0.00006, loss_test:0.13948, lr:4.80e-03, fs:0.87778 (r=0.908,p=0.849),  time:6.040, tt:446.962
# Ep:74, loss:0.00006, loss_test:0.14935, lr:4.75e-03, fs:0.87209 (r=0.862,p=0.882),  time:6.056, tt:454.178
# Ep:75, loss:0.00006, loss_test:0.15411, lr:4.71e-03, fs:0.86905 (r=0.839,p=0.901),  time:6.103, tt:463.853
# Ep:76, loss:0.00005, loss_test:0.14075, lr:4.66e-03, fs:0.89143 (r=0.897,p=0.886),  time:6.139, tt:472.682
# Ep:77, loss:0.00005, loss_test:0.15878, lr:4.61e-03, fs:0.85882 (r=0.839,p=0.880),  time:6.136, tt:478.571
# Ep:78, loss:0.00005, loss_test:0.14865, lr:4.57e-03, fs:0.87574 (r=0.851,p=0.902),  time:6.134, tt:484.562
# Ep:79, loss:0.00005, loss_test:0.14413, lr:4.52e-03, fs:0.88636 (r=0.897,p=0.876),  time:6.133, tt:490.630
# Ep:80, loss:0.00004, loss_test:0.15767, lr:4.48e-03, fs:0.87209 (r=0.862,p=0.882),  time:6.129, tt:496.446
# Ep:81, loss:0.00005, loss_test:0.15508, lr:4.43e-03, fs:0.86391 (r=0.839,p=0.890),  time:6.126, tt:502.300
# Ep:82, loss:0.00005, loss_test:0.14910, lr:4.39e-03, fs:0.85882 (r=0.839,p=0.880),  time:6.122, tt:508.098
# Ep:83, loss:0.00004, loss_test:0.15607, lr:4.34e-03, fs:0.86391 (r=0.839,p=0.890),  time:6.118, tt:513.942
# Ep:84, loss:0.00005, loss_test:0.15646, lr:4.30e-03, fs:0.80982 (r=0.759,p=0.868),  time:6.116, tt:519.859
# Ep:85, loss:0.00004, loss_test:0.15090, lr:4.26e-03, fs:0.85882 (r=0.839,p=0.880),  time:6.113, tt:525.750
# Ep:86, loss:0.00004, loss_test:0.15686, lr:4.21e-03, fs:0.86905 (r=0.839,p=0.901),  time:6.108, tt:531.428
# Ep:87, loss:0.00004, loss_test:0.15557, lr:4.17e-03, fs:0.80982 (r=0.759,p=0.868),  time:6.104, tt:537.142
# Ep:88, loss:0.00004, loss_test:0.16189, lr:4.13e-03, fs:0.82424 (r=0.782,p=0.872),  time:6.105, tt:543.367
# Ep:89, loss:0.00004, loss_test:0.15716, lr:4.09e-03, fs:0.85882 (r=0.839,p=0.880),  time:6.106, tt:549.565
# Ep:90, loss:0.00004, loss_test:0.15592, lr:4.05e-03, fs:0.83636 (r=0.793,p=0.885),  time:6.103, tt:555.387
# Ep:91, loss:0.00004, loss_test:0.16136, lr:4.01e-03, fs:0.82635 (r=0.793,p=0.863),  time:6.102, tt:561.374
# Ep:92, loss:0.00004, loss_test:0.16317, lr:3.97e-03, fs:0.85380 (r=0.839,p=0.869),  time:6.105, tt:567.741
# Ep:93, loss:0.00004, loss_test:0.16017, lr:3.93e-03, fs:0.80745 (r=0.747,p=0.878),  time:6.107, tt:574.057
# Ep:94, loss:0.00004, loss_test:0.17197, lr:3.89e-03, fs:0.77987 (r=0.713,p=0.861),  time:6.103, tt:579.768
# Ep:95, loss:0.00003, loss_test:0.16231, lr:3.85e-03, fs:0.81212 (r=0.770,p=0.859),  time:6.100, tt:585.638
# Ep:96, loss:0.00003, loss_test:0.15660, lr:3.81e-03, fs:0.85380 (r=0.839,p=0.869),  time:6.120, tt:593.629
# Ep:97, loss:0.00003, loss_test:0.16240, lr:3.77e-03, fs:0.78261 (r=0.724,p=0.851),  time:6.151, tt:602.831
# Ep:98, loss:0.00003, loss_test:0.15740, lr:3.73e-03, fs:0.84706 (r=0.828,p=0.867),  time:6.170, tt:610.832
# Ep:99, loss:0.00003, loss_test:0.16250, lr:3.70e-03, fs:0.80488 (r=0.759,p=0.857),  time:6.171, tt:617.110
# Ep:100, loss:0.00003, loss_test:0.16559, lr:3.66e-03, fs:0.81212 (r=0.770,p=0.859),  time:6.170, tt:623.205
# Ep:101, loss:0.00003, loss_test:0.15662, lr:3.62e-03, fs:0.85380 (r=0.839,p=0.869),  time:6.168, tt:629.143
# Ep:102, loss:0.00003, loss_test:0.16555, lr:3.59e-03, fs:0.76730 (r=0.701,p=0.847),  time:6.167, tt:635.154
# Ep:103, loss:0.00003, loss_test:0.16961, lr:3.55e-03, fs:0.76730 (r=0.701,p=0.847),  time:6.163, tt:640.911
# Ep:104, loss:0.00003, loss_test:0.16561, lr:3.52e-03, fs:0.86391 (r=0.839,p=0.890),  time:6.159, tt:646.731
# Ep:105, loss:0.00003, loss_test:0.16230, lr:3.48e-03, fs:0.77215 (r=0.701,p=0.859),  time:6.155, tt:652.438
# Ep:106, loss:0.00003, loss_test:0.16975, lr:3.45e-03, fs:0.79755 (r=0.747,p=0.855),  time:6.153, tt:658.326
# Ep:107, loss:0.00003, loss_test:0.16717, lr:3.41e-03, fs:0.77500 (r=0.713,p=0.849),  time:6.154, tt:664.625
# Ep:108, loss:0.00003, loss_test:0.15643, lr:3.38e-03, fs:0.77987 (r=0.713,p=0.861),  time:6.154, tt:670.736
# Ep:109, loss:0.00003, loss_test:0.17173, lr:3.34e-03, fs:0.80247 (r=0.747,p=0.867),  time:6.152, tt:676.736
# Ep:110, loss:0.00003, loss_test:0.17113, lr:3.31e-03, fs:0.78261 (r=0.724,p=0.851),  time:6.149, tt:682.530
# Ep:111, loss:0.00003, loss_test:0.15696, lr:3.28e-03, fs:0.80247 (r=0.747,p=0.867),  time:6.145, tt:688.230
# Ep:112, loss:0.00002, loss_test:0.16784, lr:3.24e-03, fs:0.76730 (r=0.701,p=0.847),  time:6.147, tt:694.562
# Ep:113, loss:0.00002, loss_test:0.17728, lr:3.21e-03, fs:0.76730 (r=0.701,p=0.847),  time:6.145, tt:700.489
# Ep:114, loss:0.00002, loss_test:0.16186, lr:3.18e-03, fs:0.77215 (r=0.701,p=0.859),  time:6.144, tt:706.547
# Ep:115, loss:0.00002, loss_test:0.15889, lr:3.15e-03, fs:0.81212 (r=0.770,p=0.859),  time:6.140, tt:712.288
# Ep:116, loss:0.00002, loss_test:0.17265, lr:3.12e-03, fs:0.80488 (r=0.759,p=0.857),  time:6.140, tt:718.415
# Ep:117, loss:0.00002, loss_test:0.16823, lr:3.09e-03, fs:0.77215 (r=0.701,p=0.859),  time:6.164, tt:727.330
# Ep:118, loss:0.00002, loss_test:0.16049, lr:3.05e-03, fs:0.77987 (r=0.713,p=0.861),  time:6.190, tt:736.596
# Ep:119, loss:0.00002, loss_test:0.16884, lr:3.02e-03, fs:0.76730 (r=0.701,p=0.847),  time:6.215, tt:745.821
# Model and results saved
# Saving best model...
# Model and results saved
# Values to load
# dataset_name=openML
# neg_sample= 0
# strategy= random_subsam
# create_new_split= False
# cross_v= 2
# Dataset splits loaded
# Train positive samples: 456 Test positive samples: 87
# Meta-feature graph from datasets loaded
# Start of training...NN Fasttext2_364 Loss CosineEmbeddingLoss Split 1024:
# Ep:0, loss:0.00062, loss_test:0.24684, lr:1.00e-02, fs:0.66667 (r=1.000,p=0.500),  time:5.490, tt:5.490
# ##########Best model found so far##########
# Ep:1, loss:0.00062, loss_test:0.24605, lr:9.90e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.627, tt:11.255
# Ep:2, loss:0.00061, loss_test:0.24446, lr:9.80e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.572, tt:16.715
# Ep:3, loss:0.00059, loss_test:0.24115, lr:9.70e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.592, tt:22.368
# Ep:4, loss:0.00055, loss_test:0.23305, lr:9.61e-03, fs:0.66667 (r=1.000,p=0.500),  time:5.629, tt:28.143
# Ep:5, loss:0.00048, loss_test:0.22043, lr:9.51e-03, fs:0.66667 (r=0.989,p=0.503),  time:5.638, tt:33.825
# Ep:6, loss:0.00040, loss_test:0.21320, lr:9.41e-03, fs:0.64407 (r=0.874,p=0.510),  time:5.520, tt:38.637
# Ep:7, loss:0.00033, loss_test:0.20949, lr:9.32e-03, fs:0.65138 (r=0.816,p=0.542),  time:5.431, tt:43.446
# Ep:8, loss:0.00032, loss_test:0.20349, lr:9.23e-03, fs:0.63810 (r=0.770,p=0.545),  time:5.362, tt:48.256
# Ep:9, loss:0.00030, loss_test:0.20390, lr:9.14e-03, fs:0.66332 (r=0.759,p=0.589),  time:5.390, tt:53.903
# Ep:10, loss:0.00030, loss_test:0.19834, lr:9.04e-03, fs:0.67000 (r=0.770,p=0.593),  time:5.434, tt:59.768
# ##########Best model found so far##########
# Ep:11, loss:0.00028, loss_test:0.19067, lr:8.95e-03, fs:0.66337 (r=0.770,p=0.583),  time:5.483, tt:65.792
# Ep:12, loss:0.00027, loss_test:0.18646, lr:8.86e-03, fs:0.67000 (r=0.770,p=0.593),  time:5.503, tt:71.538
# Ep:13, loss:0.00027, loss_test:0.18550, lr:8.78e-03, fs:0.70000 (r=0.805,p=0.619),  time:5.532, tt:77.442
# ##########Best model found so far##########
# Ep:14, loss:0.00025, loss_test:0.18185, lr:8.69e-03, fs:0.72362 (r=0.828,p=0.643),  time:5.556, tt:83.342
# ##########Best model found so far##########
# Ep:15, loss:0.00025, loss_test:0.18241, lr:8.60e-03, fs:0.74346 (r=0.816,p=0.683),  time:5.794, tt:92.705
# ##########Best model found so far##########
# Ep:16, loss:0.00024, loss_test:0.17838, lr:8.51e-03, fs:0.73846 (r=0.828,p=0.667),  time:5.947, tt:101.103
# Ep:17, loss:0.00023, loss_test:0.17959, lr:8.43e-03, fs:0.73469 (r=0.828,p=0.661),  time:6.043, tt:108.771
# Ep:18, loss:0.00023, loss_test:0.17879, lr:8.35e-03, fs:0.75000 (r=0.828,p=0.686),  time:6.027, tt:114.519
# ##########Best model found so far##########
# Ep:19, loss:0.00021, loss_test:0.17642, lr:8.26e-03, fs:0.73196 (r=0.816,p=0.664),  time:6.015, tt:120.298
# Ep:20, loss:0.00022, loss_test:0.17582, lr:8.18e-03, fs:0.77005 (r=0.828,p=0.720),  time:6.013, tt:126.276
# ##########Best model found so far##########
# Ep:21, loss:0.00020, loss_test:0.17332, lr:8.10e-03, fs:0.75789 (r=0.828,p=0.699),  time:5.991, tt:131.798
# Ep:22, loss:0.00019, loss_test:0.17068, lr:8.02e-03, fs:0.75532 (r=0.816,p=0.703),  time:5.961, tt:137.110
# Ep:23, loss:0.00019, loss_test:0.16771, lr:7.94e-03, fs:0.76440 (r=0.839,p=0.702),  time:5.932, tt:142.359
# Ep:24, loss:0.00019, loss_test:0.16563, lr:7.86e-03, fs:0.75393 (r=0.828,p=0.692),  time:5.938, tt:148.450
# Ep:25, loss:0.00018, loss_test:0.16850, lr:7.78e-03, fs:0.77174 (r=0.816,p=0.732),  time:5.928, tt:154.132
# ##########Best model found so far##########
# Ep:26, loss:0.00017, loss_test:0.16843, lr:7.70e-03, fs:0.75532 (r=0.816,p=0.703),  time:5.925, tt:159.984
# Ep:27, loss:0.00016, loss_test:0.16122, lr:7.62e-03, fs:0.72632 (r=0.793,p=0.670),  time:5.911, tt:165.501
# Ep:28, loss:0.00016, loss_test:0.16375, lr:7.55e-03, fs:0.76243 (r=0.793,p=0.734),  time:5.899, tt:171.067
# Ep:29, loss:0.00016, loss_test:0.16273, lr:7.47e-03, fs:0.75824 (r=0.793,p=0.726),  time:5.887, tt:176.607
# Ep:30, loss:0.00015, loss_test:0.15945, lr:7.40e-03, fs:0.74595 (r=0.793,p=0.704),  time:5.878, tt:182.205
# Ep:31, loss:0.00015, loss_test:0.15905, lr:7.32e-03, fs:0.75269 (r=0.805,p=0.707),  time:5.857, tt:187.412
# Ep:32, loss:0.00014, loss_test:0.15812, lr:7.25e-03, fs:0.79121 (r=0.828,p=0.758),  time:5.852, tt:193.117
# ##########Best model found so far##########
# Ep:33, loss:0.00014, loss_test:0.15610, lr:7.18e-03, fs:0.77095 (r=0.793,p=0.750),  time:5.839, tt:198.510
# Ep:34, loss:0.00014, loss_test:0.15393, lr:7.11e-03, fs:0.76503 (r=0.805,p=0.729),  time:5.824, tt:203.836
# Ep:35, loss:0.00014, loss_test:0.15820, lr:7.03e-03, fs:0.80447 (r=0.828,p=0.783),  time:5.818, tt:209.446
# ##########Best model found so far##########
# Ep:36, loss:0.00013, loss_test:0.15772, lr:6.96e-03, fs:0.77273 (r=0.782,p=0.764),  time:5.828, tt:215.646
# Ep:37, loss:0.00012, loss_test:0.15439, lr:6.89e-03, fs:0.77095 (r=0.793,p=0.750),  time:5.889, tt:223.798
# Ep:38, loss:0.00012, loss_test:0.15438, lr:6.83e-03, fs:0.78409 (r=0.793,p=0.775),  time:5.961, tt:232.494
# Ep:39, loss:0.00011, loss_test:0.15352, lr:6.76e-03, fs:0.75978 (r=0.782,p=0.739),  time:6.006, tt:240.235
# Ep:40, loss:0.00011, loss_test:0.14979, lr:6.69e-03, fs:0.77095 (r=0.793,p=0.750),  time:6.008, tt:246.325
# Ep:41, loss:0.00011, loss_test:0.15346, lr:6.62e-03, fs:0.79769 (r=0.793,p=0.802),  time:6.002, tt:252.082
# Ep:42, loss:0.00011, loss_test:0.15334, lr:6.56e-03, fs:0.78161 (r=0.782,p=0.782),  time:6.003, tt:258.113
# Ep:43, loss:0.00011, loss_test:0.15415, lr:6.49e-03, fs:0.79310 (r=0.793,p=0.793),  time:5.992, tt:263.642
# Ep:44, loss:0.00010, loss_test:0.15164, lr:6.43e-03, fs:0.78409 (r=0.793,p=0.775),  time:5.975, tt:268.864
# Ep:45, loss:0.00010, loss_test:0.15360, lr:6.36e-03, fs:0.79310 (r=0.793,p=0.793),  time:5.961, tt:274.226
# Ep:46, loss:0.00010, loss_test:0.14880, lr:6.30e-03, fs:0.78409 (r=0.793,p=0.775),  time:5.951, tt:279.682
# Ep:47, loss:0.00010, loss_test:0.15108, lr:6.24e-03, fs:0.80000 (r=0.805,p=0.795),  time:5.945, tt:285.344
# Ep:48, loss:0.00009, loss_test:0.14576, lr:6.17e-03, fs:0.80233 (r=0.793,p=0.812),  time:5.953, tt:291.694
# Ep:49, loss:0.00009, loss_test:0.15103, lr:6.11e-03, fs:0.80233 (r=0.793,p=0.812),  time:5.944, tt:297.180
# Ep:50, loss:0.00008, loss_test:0.15298, lr:6.05e-03, fs:0.81657 (r=0.793,p=0.841),  time:5.932, tt:302.549
# ##########Best model found so far##########
# Ep:51, loss:0.00008, loss_test:0.15057, lr:5.99e-03, fs:0.80233 (r=0.793,p=0.812),  time:5.920, tt:307.815
# Ep:52, loss:0.00008, loss_test:0.15087, lr:5.93e-03, fs:0.80233 (r=0.793,p=0.812),  time:5.906, tt:313.028
# Ep:53, loss:0.00008, loss_test:0.14972, lr:5.87e-03, fs:0.78857 (r=0.793,p=0.784),  time:5.901, tt:318.651
# Ep:54, loss:0.00008, loss_test:0.15313, lr:5.81e-03, fs:0.80702 (r=0.793,p=0.821),  time:5.898, tt:324.374
# Ep:55, loss:0.00008, loss_test:0.15539, lr:5.75e-03, fs:0.80702 (r=0.793,p=0.821),  time:5.914, tt:331.159
# Ep:56, loss:0.00007, loss_test:0.15329, lr:5.70e-03, fs:0.79518 (r=0.759,p=0.835),  time:5.904, tt:336.527
# Ep:57, loss:0.00007, loss_test:0.15241, lr:5.64e-03, fs:0.79042 (r=0.759,p=0.825),  time:5.906, tt:342.522
# Ep:58, loss:0.00007, loss_test:0.15252, lr:5.58e-03, fs:0.79762 (r=0.770,p=0.827),  time:5.913, tt:348.878
# Ep:59, loss:0.00007, loss_test:0.15655, lr:5.53e-03, fs:0.80723 (r=0.770,p=0.848),  time:5.954, tt:357.221
# Ep:60, loss:0.00006, loss_test:0.15772, lr:5.47e-03, fs:0.79518 (r=0.759,p=0.835),  time:5.989, tt:365.354
# Ep:61, loss:0.00006, loss_test:0.15626, lr:5.42e-03, fs:0.79518 (r=0.759,p=0.835),  time:5.989, tt:371.299
# Ep:62, loss:0.00006, loss_test:0.15336, lr:5.36e-03, fs:0.79042 (r=0.759,p=0.825),  time:5.982, tt:376.872
# Ep:63, loss:0.00006, loss_test:0.15343, lr:5.31e-03, fs:0.80488 (r=0.759,p=0.857),  time:5.985, tt:383.014
# Ep:64, loss:0.00006, loss_test:0.15493, lr:5.26e-03, fs:0.78049 (r=0.736,p=0.831),  time:5.984, tt:388.962
# Ep:65, loss:0.00006, loss_test:0.15636, lr:5.20e-03, fs:0.79518 (r=0.759,p=0.835),  time:5.982, tt:394.790
# Ep:66, loss:0.00006, loss_test:0.15741, lr:5.15e-03, fs:0.81212 (r=0.770,p=0.859),  time:5.991, tt:401.397
# Ep:67, loss:0.00005, loss_test:0.15569, lr:5.10e-03, fs:0.77647 (r=0.759,p=0.795),  time:5.991, tt:407.374
# Ep:68, loss:0.00005, loss_test:0.15285, lr:5.05e-03, fs:0.78528 (r=0.736,p=0.842),  time:5.988, tt:413.183
# Ep:69, loss:0.00006, loss_test:0.15507, lr:5.00e-03, fs:0.80982 (r=0.759,p=0.868),  time:5.992, tt:419.471
# Ep:70, loss:0.00005, loss_test:0.15749, lr:4.95e-03, fs:0.80000 (r=0.759,p=0.846),  time:5.991, tt:425.350
# Ep:71, loss:0.00005, loss_test:0.15979, lr:4.90e-03, fs:0.79503 (r=0.736,p=0.865),  time:5.988, tt:431.146
# Ep:72, loss:0.00005, loss_test:0.15807, lr:4.85e-03, fs:0.79012 (r=0.736,p=0.853),  time:5.987, tt:437.031
# Ep:73, loss:0.00005, loss_test:0.15954, lr:4.80e-03, fs:0.80982 (r=0.759,p=0.868),  time:5.986, tt:442.931
# Ep:74, loss:0.00004, loss_test:0.15675, lr:4.75e-03, fs:0.81707 (r=0.770,p=0.870),  time:5.985, tt:448.882
# ##########Best model found so far##########
# Ep:75, loss:0.00004, loss_test:0.15929, lr:4.71e-03, fs:0.81481 (r=0.759,p=0.880),  time:5.984, tt:454.804
# Ep:76, loss:0.00005, loss_test:0.16345, lr:4.66e-03, fs:0.79012 (r=0.736,p=0.853),  time:5.981, tt:460.503
# Ep:77, loss:0.00004, loss_test:0.16470, lr:4.61e-03, fs:0.78528 (r=0.736,p=0.842),  time:5.978, tt:466.245
# Ep:78, loss:0.00004, loss_test:0.16012, lr:4.57e-03, fs:0.80000 (r=0.736,p=0.877),  time:5.972, tt:471.810
# Ep:79, loss:0.00004, loss_test:0.15770, lr:4.52e-03, fs:0.80982 (r=0.759,p=0.868),  time:5.967, tt:477.356
# Ep:80, loss:0.00004, loss_test:0.16042, lr:4.48e-03, fs:0.80982 (r=0.759,p=0.868),  time:5.963, tt:483.021
# Ep:81, loss:0.00004, loss_test:0.16192, lr:4.43e-03, fs:0.81212 (r=0.770,p=0.859),  time:5.992, tt:491.361
# Ep:82, loss:0.00004, loss_test:0.16075, lr:4.39e-03, fs:0.80982 (r=0.759,p=0.868),  time:6.021, tt:499.719
# Ep:83, loss:0.00004, loss_test:0.16424, lr:4.34e-03, fs:0.81481 (r=0.759,p=0.880),  time:6.017, tt:505.419
# Ep:84, loss:0.00004, loss_test:0.17337, lr:4.30e-03, fs:0.75325 (r=0.667,p=0.866),  time:6.007, tt:510.617
# Ep:85, loss:0.00004, loss_test:0.16778, lr:4.26e-03, fs:0.79503 (r=0.736,p=0.865),  time:6.011, tt:516.927
# Ep:86, loss:0.00004, loss_test:0.15995, lr:4.21e-03, fs:0.80982 (r=0.759,p=0.868),  time:6.005, tt:522.467
# Ep:87, loss:0.00004, loss_test:0.16463, lr:4.17e-03, fs:0.81481 (r=0.759,p=0.880),  time:5.999, tt:527.919
# Ep:88, loss:0.00004, loss_test:0.17354, lr:4.13e-03, fs:0.76923 (r=0.690,p=0.870),  time:5.994, tt:533.421
# Ep:89, loss:0.00004, loss_test:0.17380, lr:4.09e-03, fs:0.79012 (r=0.736,p=0.853),  time:5.987, tt:538.833
# Ep:90, loss:0.00004, loss_test:0.17272, lr:4.05e-03, fs:0.78481 (r=0.713,p=0.873),  time:5.982, tt:544.323
# Ep:91, loss:0.00003, loss_test:0.17399, lr:4.01e-03, fs:0.75325 (r=0.667,p=0.866),  time:5.977, tt:549.903
# Ep:92, loss:0.00003, loss_test:0.17051, lr:3.97e-03, fs:0.78481 (r=0.713,p=0.873),  time:5.972, tt:555.373
# Ep:93, loss:0.00003, loss_test:0.17083, lr:3.93e-03, fs:0.72848 (r=0.632,p=0.859),  time:5.967, tt:560.933
# Ep:94, loss:0.00003, loss_test:0.17317, lr:3.89e-03, fs:0.74510 (r=0.655,p=0.864),  time:5.965, tt:566.659
# Ep:95, loss:0.00003, loss_test:0.17694, lr:3.85e-03, fs:0.70270 (r=0.598,p=0.852),  time:5.963, tt:572.462
# Ep:96, loss:0.00003, loss_test:0.17952, lr:3.81e-03, fs:0.70270 (r=0.598,p=0.852),  time:5.969, tt:578.964
# Ep:97, loss:0.00003, loss_test:0.17918, lr:3.77e-03, fs:0.72848 (r=0.632,p=0.859),  time:5.968, tt:584.822
# Ep:98, loss:0.00003, loss_test:0.17857, lr:3.73e-03, fs:0.72000 (r=0.621,p=0.857),  time:5.970, tt:591.072
# Ep:99, loss:0.00003, loss_test:0.17783, lr:3.70e-03, fs:0.72000 (r=0.621,p=0.857),  time:5.972, tt:597.181
# Ep:100, loss:0.00003, loss_test:0.17614, lr:3.66e-03, fs:0.75000 (r=0.655,p=0.877),  time:5.970, tt:602.969
# Ep:101, loss:0.00003, loss_test:0.17869, lr:3.62e-03, fs:0.72000 (r=0.621,p=0.857),  time:5.970, tt:608.976
# Ep:102, loss:0.00002, loss_test:0.18038, lr:3.59e-03, fs:0.70270 (r=0.598,p=0.852),  time:5.993, tt:617.305
# Ep:103, loss:0.00002, loss_test:0.17708, lr:3.55e-03, fs:0.70270 (r=0.598,p=0.852),  time:6.023, tt:626.362
# Ep:104, loss:0.00003, loss_test:0.17919, lr:3.52e-03, fs:0.70748 (r=0.598,p=0.867),  time:6.033, tt:633.417
# Ep:105, loss:0.00003, loss_test:0.18745, lr:3.48e-03, fs:0.70748 (r=0.598,p=0.867),  time:6.033, tt:639.513
# Ep:106, loss:0.00002, loss_test:0.18115, lr:3.45e-03, fs:0.71141 (r=0.609,p=0.855),  time:6.037, tt:645.974
# Ep:107, loss:0.00002, loss_test:0.17752, lr:3.41e-03, fs:0.70748 (r=0.598,p=0.867),  time:6.032, tt:651.480
# Ep:108, loss:0.00002, loss_test:0.18103, lr:3.38e-03, fs:0.72848 (r=0.632,p=0.859),  time:6.028, tt:657.011
# Ep:109, loss:0.00002, loss_test:0.17959, lr:3.34e-03, fs:0.72000 (r=0.621,p=0.857),  time:6.020, tt:662.185
# Ep:110, loss:0.00002, loss_test:0.17681, lr:3.31e-03, fs:0.74172 (r=0.644,p=0.875),  time:6.015, tt:667.678
# Ep:111, loss:0.00002, loss_test:0.18000, lr:3.28e-03, fs:0.70748 (r=0.598,p=0.867),  time:6.011, tt:673.198
# Ep:112, loss:0.00002, loss_test:0.18078, lr:3.24e-03, fs:0.70270 (r=0.598,p=0.852),  time:6.006, tt:678.642
# Ep:113, loss:0.00002, loss_test:0.18341, lr:3.21e-03, fs:0.70748 (r=0.598,p=0.867),  time:6.009, tt:684.978
# Ep:114, loss:0.00002, loss_test:0.18252, lr:3.18e-03, fs:0.71233 (r=0.598,p=0.881),  time:6.002, tt:690.176
# Ep:115, loss:0.00002, loss_test:0.18165, lr:3.15e-03, fs:0.70748 (r=0.598,p=0.867),  time:5.996, tt:695.545
# Ep:116, loss:0.00002, loss_test:0.17876, lr:3.12e-03, fs:0.70748 (r=0.598,p=0.867),  time:5.994, tt:701.284
# Ep:117, loss:0.00002, loss_test:0.18040, lr:3.09e-03, fs:0.71724 (r=0.598,p=0.897),  time:5.990, tt:706.865
# Ep:118, loss:0.00002, loss_test:0.18343, lr:3.05e-03, fs:0.70748 (r=0.598,p=0.867),  time:5.988, tt:712.567
# Ep:119, loss:0.00002, loss_test:0.18104, lr:3.02e-03, fs:0.70748 (r=0.598,p=0.867),  time:5.978, tt:717.383
# Model and results saved
# Saving best model...
# Model and results saved
# Values to load
# dataset_name=openML
# neg_sample= 0
# strategy= random_subsam
# create_new_split= False
# cross_v= 3
# Dataset splits loaded
# Train positive samples: 456 Test positive samples: 87
# Meta-feature graph from datasets loaded
# Start of training...NN Fasttext2_364 Loss CosineEmbeddingLoss Split 1024:
# Ep:0, loss:0.00062, loss_test:0.24487, lr:1.00e-02, fs:0.66667 (r=1.000,p=0.500),  time:6.447, tt:6.447
# ##########Best model found so far##########
# Ep:1, loss:0.00062, loss_test:0.24348, lr:9.90e-03, fs:0.66667 (r=1.000,p=0.500),  time:7.577, tt:15.153
# Ep:2, loss:0.00061, loss_test:0.24070, lr:9.80e-03, fs:0.66667 (r=1.000,p=0.500),  time:7.954, tt:23.863
# Ep:3, loss:0.00059, loss_test:0.23517, lr:9.70e-03, fs:0.66667 (r=1.000,p=0.500),  time:7.680, tt:30.719
# Ep:4, loss:0.00055, loss_test:0.22363, lr:9.61e-03, fs:0.66667 (r=1.000,p=0.500),  time:7.339, tt:36.694
# Ep:5, loss:0.00049, loss_test:0.20626, lr:9.51e-03, fs:0.65854 (r=0.931,p=0.509),  time:7.095, tt:42.571
# Ep:6, loss:0.00040, loss_test:0.19457, lr:9.41e-03, fs:0.66667 (r=0.862,p=0.543),  time:6.872, tt:48.101
# Ep:7, loss:0.00033, loss_test:0.19413, lr:9.32e-03, fs:0.69903 (r=0.828,p=0.605),  time:6.805, tt:54.442
# ##########Best model found so far##########
# Ep:8, loss:0.00031, loss_test:0.19140, lr:9.23e-03, fs:0.69307 (r=0.805,p=0.609),  time:6.589, tt:59.305
# Ep:9, loss:0.00031, loss_test:0.19381, lr:9.14e-03, fs:0.69945 (r=0.736,p=0.667),  time:6.407, tt:64.075
# ##########Best model found so far##########
# Ep:10, loss:0.00029, loss_test:0.18748, lr:9.04e-03, fs:0.70526 (r=0.770,p=0.650),  time:6.259, tt:68.851
# ##########Best model found so far##########
# Ep:11, loss:0.00029, loss_test:0.18302, lr:8.95e-03, fs:0.72632 (r=0.793,p=0.670),  time:6.246, tt:74.950
# ##########Best model found so far##########
# Ep:12, loss:0.00027, loss_test:0.17755, lr:8.86e-03, fs:0.73016 (r=0.793,p=0.676),  time:6.197, tt:80.567
# ##########Best model found so far##########
# Ep:13, loss:0.00027, loss_test:0.16864, lr:8.78e-03, fs:0.72917 (r=0.805,p=0.667),  time:6.202, tt:86.823
# Ep:14, loss:0.00026, loss_test:0.16647, lr:8.69e-03, fs:0.76344 (r=0.816,p=0.717),  time:6.191, tt:92.871
# ##########Best model found so far##########
# Ep:15, loss:0.00025, loss_test:0.16035, lr:8.60e-03, fs:0.77083 (r=0.851,p=0.705),  time:6.216, tt:99.450
# ##########Best model found so far##########
# Ep:16, loss:0.00024, loss_test:0.15562, lr:8.51e-03, fs:0.81000 (r=0.931,p=0.717),  time:6.205, tt:105.487
# ##########Best model found so far##########
# Ep:17, loss:0.00024, loss_test:0.15226, lr:8.43e-03, fs:0.82000 (r=0.943,p=0.726),  time:6.220, tt:111.957
# ##########Best model found so far##########
# Ep:18, loss:0.00023, loss_test:0.15039, lr:8.35e-03, fs:0.82292 (r=0.908,p=0.752),  time:6.197, tt:117.745
# ##########Best model found so far##########
# Ep:19, loss:0.00022, loss_test:0.14090, lr:8.26e-03, fs:0.83168 (r=0.966,p=0.730),  time:6.202, tt:124.042
# ##########Best model found so far##########
# Ep:20, loss:0.00022, loss_test:0.14103, lr:8.18e-03, fs:0.86010 (r=0.954,p=0.783),  time:6.193, tt:130.058
# ##########Best model found so far##########
# Ep:21, loss:0.00020, loss_test:0.13990, lr:8.10e-03, fs:0.84103 (r=0.943,p=0.759),  time:6.199, tt:136.377
# Ep:22, loss:0.00020, loss_test:0.13182, lr:8.02e-03, fs:0.84848 (r=0.966,p=0.757),  time:6.332, tt:145.635
# Ep:23, loss:0.00020, loss_test:0.13096, lr:7.94e-03, fs:0.87958 (r=0.966,p=0.808),  time:6.441, tt:154.572
# ##########Best model found so far##########
# Ep:24, loss:0.00019, loss_test:0.12678, lr:7.86e-03, fs:0.86735 (r=0.977,p=0.780),  time:6.533, tt:163.334
# Ep:25, loss:0.00018, loss_test:0.12182, lr:7.78e-03, fs:0.85714 (r=0.966,p=0.771),  time:6.515, tt:169.378
# Ep:26, loss:0.00018, loss_test:0.12415, lr:7.70e-03, fs:0.90323 (r=0.966,p=0.848),  time:6.501, tt:175.534
# ##########Best model found so far##########
# Ep:27, loss:0.00017, loss_test:0.11532, lr:7.62e-03, fs:0.84577 (r=0.977,p=0.746),  time:6.484, tt:181.545
# Ep:28, loss:0.00017, loss_test:0.11733, lr:7.55e-03, fs:0.89947 (r=0.977,p=0.833),  time:6.456, tt:187.234
# Ep:29, loss:0.00016, loss_test:0.11735, lr:7.47e-03, fs:0.89474 (r=0.977,p=0.825),  time:6.451, tt:193.540
# Ep:30, loss:0.00016, loss_test:0.11034, lr:7.40e-03, fs:0.89005 (r=0.977,p=0.817),  time:6.425, tt:199.184
# Ep:31, loss:0.00015, loss_test:0.11034, lr:7.32e-03, fs:0.89947 (r=0.977,p=0.833),  time:6.406, tt:205.004
# Ep:32, loss:0.00015, loss_test:0.10966, lr:7.25e-03, fs:0.89474 (r=0.977,p=0.825),  time:6.378, tt:210.480
# Ep:33, loss:0.00014, loss_test:0.11269, lr:7.18e-03, fs:0.90217 (r=0.954,p=0.856),  time:6.363, tt:216.343
# Ep:34, loss:0.00014, loss_test:0.10460, lr:7.11e-03, fs:0.89947 (r=0.977,p=0.833),  time:6.346, tt:222.116
# Ep:35, loss:0.00014, loss_test:0.10487, lr:7.03e-03, fs:0.89947 (r=0.977,p=0.833),  time:6.323, tt:227.620
# Ep:36, loss:0.00013, loss_test:0.09759, lr:6.96e-03, fs:0.90426 (r=0.977,p=0.842),  time:6.315, tt:233.666
# ##########Best model found so far##########
# Ep:37, loss:0.00013, loss_test:0.09797, lr:6.89e-03, fs:0.90426 (r=0.977,p=0.842),  time:6.303, tt:239.527
# Ep:38, loss:0.00012, loss_test:0.09762, lr:6.83e-03, fs:0.88205 (r=0.989,p=0.796),  time:6.303, tt:245.819
# Ep:39, loss:0.00011, loss_test:0.10213, lr:6.76e-03, fs:0.92391 (r=0.977,p=0.876),  time:6.295, tt:251.792
# ##########Best model found so far##########
# Ep:40, loss:0.00011, loss_test:0.09460, lr:6.69e-03, fs:0.90526 (r=0.989,p=0.835),  time:6.299, tt:258.255
# Ep:41, loss:0.00011, loss_test:0.09367, lr:6.62e-03, fs:0.91489 (r=0.989,p=0.851),  time:6.298, tt:264.506
# Ep:42, loss:0.00011, loss_test:0.09386, lr:6.56e-03, fs:0.92391 (r=0.977,p=0.876),  time:6.273, tt:269.758
# Ep:43, loss:0.00011, loss_test:0.09203, lr:6.49e-03, fs:0.91398 (r=0.977,p=0.859),  time:6.261, tt:275.480
# Ep:44, loss:0.00011, loss_test:0.09182, lr:6.43e-03, fs:0.91398 (r=0.977,p=0.859),  time:6.342, tt:285.384
# ...
# Ep:105, loss:0.00002, loss_test:0.16608, lr:3.48e-03, fs:0.74126 (r=0.609,p=0.946),  time:3.804, tt:403.229
# Ep:106, loss:0.00002, loss_test:0.17258, lr:3.45e-03, fs:0.73611 (r=0.609,p=0.930),  time:3.804, tt:407.058
# Ep:107, loss:0.00002, loss_test:0.17241, lr:3.41e-03, fs:0.73611 (r=0.609,p=0.930),  time:3.804, tt:410.866
# Ep:108, loss:0.00002, loss_test:0.17033, lr:3.38e-03, fs:0.72727 (r=0.598,p=0.929),  time:3.805, tt:414.733
# Ep:109, loss:0.00002, loss_test:0.17147, lr:3.34e-03, fs:0.73611 (r=0.609,p=0.930),  time:3.805, tt:418.558
# Ep:110, loss:0.00002, loss_test:0.17393, lr:3.31e-03, fs:0.73611 (r=0.609,p=0.930),  time:3.805, tt:422.352
# Ep:111, loss:0.00002, loss_test:0.16889, lr:3.28e-03, fs:0.73611 (r=0.609,p=0.930),  time:3.805, tt:426.166
# Ep:112, loss:0.00002, loss_test:0.16872, lr:3.24e-03, fs:0.73611 (r=0.609,p=0.930),  time:3.805, tt:429.937
# Ep:113, loss:0.00002, loss_test:0.17287, lr:3.21e-03, fs:0.73611 (r=0.609,p=0.930),  time:3.805, tt:433.733
# Ep:114, loss:0.00002, loss_test:0.17121, lr:3.18e-03, fs:0.73103 (r=0.609,p=0.914),  time:3.805, tt:437.551
# Ep:115, loss:0.00002, loss_test:0.16998, lr:3.15e-03, fs:0.73611 (r=0.609,p=0.930),  time:3.804, tt:441.319
# Ep:116, loss:0.00002, loss_test:0.16807, lr:3.12e-03, fs:0.73611 (r=0.609,p=0.930),  time:3.804, tt:445.104
# Ep:117, loss:0.00002, loss_test:0.16908, lr:3.09e-03, fs:0.73611 (r=0.609,p=0.930),  time:3.804, tt:448.911
# Ep:118, loss:0.00002, loss_test:0.16893, lr:3.05e-03, fs:0.73611 (r=0.609,p=0.930),  time:3.804, tt:452.683
# Ep:119, loss:0.00002, loss_test:0.16728, lr:3.02e-03, fs:0.73611 (r=0.609,p=0.930),  time:3.804, tt:456.497
# Model and results saved
# Saving best model...
# Model and results saved
# Values to load
# dataset_name=openML
# neg_sample= 0
# strategy= random_subsam
# create_new_split= False
# cross_v= 19
# Dataset splits loaded
# Train positive samples: 456 Test positive samples: 87
# Meta-feature graph from datasets loaded
# Start of training...NN Fasttext2_364 Loss CosineEmbeddingLoss Split 1024:
# Ep:0, loss:0.00062, loss_test:0.24392, lr:1.00e-02, fs:0.66667 (r=1.000,p=0.500),  time:3.835, tt:3.835
# ##########Best model found so far##########
# Ep:1, loss:0.00062, loss_test:0.24236, lr:9.90e-03, fs:0.66667 (r=1.000,p=0.500),  time:3.818, tt:7.636
# Ep:2, loss:0.00061, loss_test:0.23918, lr:9.80e-03, fs:0.66667 (r=1.000,p=0.500),  time:3.815, tt:11.444
# Ep:3, loss:0.00059, loss_test:0.23335, lr:9.70e-03, fs:0.66667 (r=1.000,p=0.500),  time:3.812, tt:15.248
# Ep:4, loss:0.00056, loss_test:0.22178, lr:9.61e-03, fs:0.66667 (r=1.000,p=0.500),  time:3.815, tt:19.073
# Ep:5, loss:0.00049, loss_test:0.20346, lr:9.51e-03, fs:0.66403 (r=0.966,p=0.506),  time:3.820, tt:22.921
# Ep:6, loss:0.00041, loss_test:0.19218, lr:9.41e-03, fs:0.69869 (r=0.920,p=0.563),  time:3.822, tt:26.754
# ##########Best model found so far##########
# Ep:7, loss:0.00034, loss_test:0.18928, lr:9.32e-03, fs:0.69194 (r=0.839,p=0.589),  time:3.821, tt:30.566
# Ep:8, loss:0.00032, loss_test:0.18529, lr:9.23e-03, fs:0.69231 (r=0.828,p=0.595),  time:3.821, tt:34.388
# Ep:9, loss:0.00030, loss_test:0.18682, lr:9.14e-03, fs:0.70297 (r=0.816,p=0.617),  time:3.822, tt:38.220
# ##########Best model found so far##########
# Ep:10, loss:0.00029, loss_test:0.18111, lr:9.04e-03, fs:0.70531 (r=0.839,p=0.608),  time:3.825, tt:42.078
# ##########Best model found so far##########
# Ep:11, loss:0.00028, loss_test:0.17495, lr:8.95e-03, fs:0.70874 (r=0.839,p=0.613),  time:3.830, tt:45.958
# ##########Best model found so far##########
# Ep:12, loss:0.00028, loss_test:0.17506, lr:8.86e-03, fs:0.71287 (r=0.828,p=0.626),  time:3.830, tt:49.786
# ##########Best model found so far##########
# Ep:13, loss:0.00026, loss_test:0.16864, lr:8.78e-03, fs:0.72549 (r=0.851,p=0.632),  time:3.829, tt:53.607
# ##########Best model found so far##########
# Ep:14, loss:0.00026, loss_test:0.16254, lr:8.69e-03, fs:0.74510 (r=0.874,p=0.650),  time:3.830, tt:57.445
# ##########Best model found so far##########
# Ep:15, loss:0.00025, loss_test:0.16201, lr:8.60e-03, fs:0.75758 (r=0.862,p=0.676),  time:3.829, tt:61.267
# ##########Best model found so far##########
# Ep:16, loss:0.00024, loss_test:0.16099, lr:8.51e-03, fs:0.76142 (r=0.862,p=0.682),  time:3.828, tt:65.078
# ##########Best model found so far##########
# Ep:17, loss:0.00023, loss_test:0.15634, lr:8.43e-03, fs:0.76768 (r=0.874,p=0.685),  time:3.834, tt:69.017
# ##########Best model found so far##########
# Ep:18, loss:0.00023, loss_test:0.15827, lr:8.35e-03, fs:0.78534 (r=0.862,p=0.721),  time:3.835, tt:72.871
# ##########Best model found so far##########
# Ep:19, loss:0.00022, loss_test:0.15485, lr:8.26e-03, fs:0.76923 (r=0.862,p=0.694),  time:3.835, tt:76.701
# Ep:20, loss:0.00022, loss_test:0.14772, lr:8.18e-03, fs:0.75862 (r=0.885,p=0.664),  time:3.835, tt:80.530
# Ep:21, loss:0.00020, loss_test:0.14365, lr:8.10e-03, fs:0.78974 (r=0.885,p=0.713),  time:3.836, tt:84.399
# ##########Best model found so far##########
# Ep:22, loss:0.00020, loss_test:0.13942, lr:8.02e-03, fs:0.80412 (r=0.897,p=0.729),  time:3.837, tt:88.240
# ##########Best model found so far##########
# Ep:23, loss:0.00019, loss_test:0.13645, lr:7.94e-03, fs:0.79592 (r=0.897,p=0.716),  time:3.839, tt:92.132
# Ep:24, loss:0.00019, loss_test:0.14227, lr:7.86e-03, fs:0.80628 (r=0.885,p=0.740),  time:3.840, tt:95.988
# ##########Best model found so far##########
# Ep:25, loss:0.00019, loss_test:0.13802, lr:7.78e-03, fs:0.80412 (r=0.897,p=0.729),  time:3.840, tt:99.833
# Ep:26, loss:0.00018, loss_test:0.13644, lr:7.70e-03, fs:0.81675 (r=0.897,p=0.750),  time:3.841, tt:103.712
# ##########Best model found so far##########
# Ep:27, loss:0.00017, loss_test:0.12674, lr:7.62e-03, fs:0.80612 (r=0.908,p=0.725),  time:3.842, tt:107.568
# Ep:28, loss:0.00017, loss_test:0.13371, lr:7.55e-03, fs:0.80628 (r=0.885,p=0.740),  time:3.843, tt:111.454
# Ep:29, loss:0.00016, loss_test:0.12844, lr:7.47e-03, fs:0.81026 (r=0.908,p=0.731),  time:3.843, tt:115.297
# Ep:30, loss:0.00016, loss_test:0.12681, lr:7.40e-03, fs:0.80829 (r=0.897,p=0.736),  time:3.842, tt:119.105
# Ep:31, loss:0.00015, loss_test:0.12584, lr:7.32e-03, fs:0.82540 (r=0.897,p=0.765),  time:3.842, tt:122.945
# ##########Best model found so far##########
# Ep:32, loss:0.00015, loss_test:0.12998, lr:7.25e-03, fs:0.79793 (r=0.885,p=0.726),  time:3.841, tt:126.750
# Ep:33, loss:0.00015, loss_test:0.11601, lr:7.18e-03, fs:0.82474 (r=0.920,p=0.748),  time:3.841, tt:130.583
# Ep:34, loss:0.00014, loss_test:0.12097, lr:7.11e-03, fs:0.83598 (r=0.908,p=0.775),  time:3.841, tt:134.440
# ##########Best model found so far##########
# Ep:35, loss:0.00013, loss_test:0.11914, lr:7.03e-03, fs:0.83871 (r=0.897,p=0.788),  time:3.843, tt:138.354
# ##########Best model found so far##########
# Ep:36, loss:0.00013, loss_test:0.11302, lr:6.96e-03, fs:0.84043 (r=0.908,p=0.782),  time:3.842, tt:142.170
# ##########Best model found so far##########
# Ep:37, loss:0.00013, loss_test:0.12524, lr:6.89e-03, fs:0.82353 (r=0.885,p=0.770),  time:3.843, tt:146.051
# Ep:38, loss:0.00012, loss_test:0.11677, lr:6.83e-03, fs:0.83158 (r=0.908,p=0.767),  time:3.843, tt:149.883
# Ep:39, loss:0.00012, loss_test:0.12072, lr:6.76e-03, fs:0.81283 (r=0.874,p=0.760),  time:3.843, tt:153.709
# Ep:40, loss:0.00012, loss_test:0.11886, lr:6.69e-03, fs:0.83243 (r=0.885,p=0.786),  time:3.843, tt:157.560
# Ep:41, loss:0.00011, loss_test:0.10958, lr:6.62e-03, fs:0.84492 (r=0.908,p=0.790),  time:3.844, tt:161.431
# ##########Best model found so far##########
# Ep:42, loss:0.00011, loss_test:0.11637, lr:6.56e-03, fs:0.83871 (r=0.897,p=0.788),  time:3.844, tt:165.300
# Ep:43, loss:0.00010, loss_test:0.11692, lr:6.49e-03, fs:0.83333 (r=0.862,p=0.806),  time:3.843, tt:169.114
# Ep:44, loss:0.00011, loss_test:0.11219, lr:6.43e-03, fs:0.82222 (r=0.851,p=0.796),  time:3.843, tt:172.928
# Ep:45, loss:0.00010, loss_test:0.10774, lr:6.36e-03, fs:0.85106 (r=0.920,p=0.792),  time:3.843, tt:176.759
# ##########Best model found so far##########
# Ep:46, loss:0.00009, loss_test:0.10910, lr:6.30e-03, fs:0.86022 (r=0.920,p=0.808),  time:3.842, tt:180.559
# ##########Best model found so far##########
# Ep:47, loss:0.00009, loss_test:0.11542, lr:6.24e-03, fs:0.80874 (r=0.851,p=0.771),  time:3.842, tt:184.413
# Ep:48, loss:0.00009, loss_test:0.11227, lr:6.17e-03, fs:0.86667 (r=0.897,p=0.839),  time:3.841, tt:188.221
# ##########Best model found so far##########
# Ep:49, loss:0.00009, loss_test:0.11237, lr:6.11e-03, fs:0.86667 (r=0.897,p=0.839),  time:3.842, tt:192.100
# Ep:50, loss:0.00008, loss_test:0.11278, lr:6.05e-03, fs:0.84153 (r=0.885,p=0.802),  time:3.859, tt:196.817
# Ep:51, loss:0.00009, loss_test:0.11010, lr:5.99e-03, fs:0.88398 (r=0.920,p=0.851),  time:3.877, tt:201.607
# ##########Best model found so far##########
# Ep:52, loss:0.00008, loss_test:0.11535, lr:5.93e-03, fs:0.83429 (r=0.839,p=0.830),  time:3.879, tt:205.596
# Ep:53, loss:0.00008, loss_test:0.10455, lr:5.87e-03, fs:0.86667 (r=0.897,p=0.839),  time:3.878, tt:209.429
# Ep:54, loss:0.00008, loss_test:0.11782, lr:5.81e-03, fs:0.87293 (r=0.908,p=0.840),  time:3.876, tt:213.197
# Ep:55, loss:0.00008, loss_test:0.11060, lr:5.75e-03, fs:0.84393 (r=0.839,p=0.849),  time:3.875, tt:217.013
# Ep:56, loss:0.00008, loss_test:0.10806, lr:5.70e-03, fs:0.87059 (r=0.851,p=0.892),  time:3.874, tt:220.810
# Ep:57, loss:0.00007, loss_test:0.11804, lr:5.64e-03, fs:0.86364 (r=0.874,p=0.854),  time:3.873, tt:224.614
# Ep:58, loss:0.00007, loss_test:0.10768, lr:5.58e-03, fs:0.82955 (r=0.839,p=0.820),  time:3.872, tt:228.440
# Ep:59, loss:0.00007, loss_test:0.11196, lr:5.53e-03, fs:0.85227 (r=0.862,p=0.843),  time:3.870, tt:232.229
# Ep:60, loss:0.00006, loss_test:0.11103, lr:5.47e-03, fs:0.84884 (r=0.839,p=0.859),  time:3.869, tt:236.014
# Ep:61, loss:0.00006, loss_test:0.11117, lr:5.42e-03, fs:0.84884 (r=0.839,p=0.859),  time:3.868, tt:239.799
# Ep:62, loss:0.00006, loss_test:0.11525, lr:5.36e-03, fs:0.83429 (r=0.839,p=0.830),  time:3.866, tt:243.576
# Ep:63, loss:0.00006, loss_test:0.10884, lr:5.31e-03, fs:0.85380 (r=0.839,p=0.869),  time:3.865, tt:247.331
# Ep:64, loss:0.00005, loss_test:0.10944, lr:5.26e-03, fs:0.87425 (r=0.839,p=0.912),  time:3.863, tt:251.122
# Ep:65, loss:0.00006, loss_test:0.11423, lr:5.20e-03, fs:0.85882 (r=0.839,p=0.880),  time:3.863, tt:254.937
# Ep:66, loss:0.00005, loss_test:0.11499, lr:5.15e-03, fs:0.84393 (r=0.839,p=0.849),  time:3.862, tt:258.744
# Ep:67, loss:0.00005, loss_test:0.10873, lr:5.10e-03, fs:0.84884 (r=0.839,p=0.859),  time:3.861, tt:262.577
# Ep:68, loss:0.00005, loss_test:0.11153, lr:5.05e-03, fs:0.86550 (r=0.851,p=0.881),  time:3.861, tt:266.379
# Ep:69, loss:0.00005, loss_test:0.11190, lr:5.00e-03, fs:0.85882 (r=0.839,p=0.880),  time:3.860, tt:270.191
# Ep:70, loss:0.00005, loss_test:0.10994, lr:4.95e-03, fs:0.85380 (r=0.839,p=0.869),  time:3.859, tt:273.995
# Ep:71, loss:0.00005, loss_test:0.11738, lr:4.90e-03, fs:0.85380 (r=0.839,p=0.869),  time:3.858, tt:277.790
# Ep:72, loss:0.00004, loss_test:0.11446, lr:4.85e-03, fs:0.86905 (r=0.839,p=0.901),  time:3.857, tt:281.578
# Ep:73, loss:0.00005, loss_test:0.11019, lr:4.80e-03, fs:0.85380 (r=0.839,p=0.869),  time:3.856, tt:285.326
# Ep:74, loss:0.00005, loss_test:0.11943, lr:4.75e-03, fs:0.85207 (r=0.828,p=0.878),  time:3.855, tt:289.135
# Ep:75, loss:0.00004, loss_test:0.11478, lr:4.71e-03, fs:0.86391 (r=0.839,p=0.890),  time:3.854, tt:292.895
# Ep:76, loss:0.00004, loss_test:0.11411, lr:4.66e-03, fs:0.85882 (r=0.839,p=0.880),  time:3.853, tt:296.692
# Ep:77, loss:0.00004, loss_test:0.11762, lr:4.61e-03, fs:0.85882 (r=0.839,p=0.880),  time:3.853, tt:300.505
# Ep:78, loss:0.00004, loss_test:0.12067, lr:4.57e-03, fs:0.80247 (r=0.747,p=0.867),  time:3.852, tt:304.275
# Ep:79, loss:0.00004, loss_test:0.12095, lr:4.52e-03, fs:0.80247 (r=0.747,p=0.867),  time:3.851, tt:308.098
# Ep:80, loss:0.00004, loss_test:0.11759, lr:4.48e-03, fs:0.86391 (r=0.839,p=0.890),  time:3.851, tt:311.959
# Ep:81, loss:0.00004, loss_test:0.12115, lr:4.43e-03, fs:0.83832 (r=0.805,p=0.875),  time:3.851, tt:315.771
# Ep:82, loss:0.00003, loss_test:0.12260, lr:4.39e-03, fs:0.82278 (r=0.747,p=0.915),  time:3.851, tt:319.603
# Ep:83, loss:0.00004, loss_test:0.12315, lr:4.34e-03, fs:0.78261 (r=0.724,p=0.851),  time:3.851, tt:323.521
# Ep:84, loss:0.00004, loss_test:0.11983, lr:4.30e-03, fs:0.86905 (r=0.839,p=0.901),  time:3.851, tt:327.367
# Ep:85, loss:0.00003, loss_test:0.13114, lr:4.26e-03, fs:0.77215 (r=0.701,p=0.859),  time:3.851, tt:331.176
# Ep:86, loss:0.00003, loss_test:0.12448, lr:4.21e-03, fs:0.79747 (r=0.724,p=0.887),  time:3.851, tt:335.059
# Ep:87, loss:0.00003, loss_test:0.12516, lr:4.17e-03, fs:0.80503 (r=0.736,p=0.889),  time:3.851, tt:338.879
# Ep:88, loss:0.00003, loss_test:0.12816, lr:4.13e-03, fs:0.77215 (r=0.701,p=0.859),  time:3.850, tt:342.663
# Ep:89, loss:0.00003, loss_test:0.12687, lr:4.09e-03, fs:0.77215 (r=0.701,p=0.859),  time:3.850, tt:346.503
# Ep:90, loss:0.00003, loss_test:0.12883, lr:4.05e-03, fs:0.78205 (r=0.701,p=0.884),  time:3.850, tt:350.343
# Ep:91, loss:0.00003, loss_test:0.13356, lr:4.01e-03, fs:0.80255 (r=0.724,p=0.900),  time:3.850, tt:354.231
# Ep:92, loss:0.00003, loss_test:0.12915, lr:3.97e-03, fs:0.78205 (r=0.701,p=0.884),  time:3.850, tt:358.020
# Ep:93, loss:0.00003, loss_test:0.13081, lr:3.93e-03, fs:0.76730 (r=0.701,p=0.847),  time:3.849, tt:361.822
# Ep:94, loss:0.00003, loss_test:0.12881, lr:3.89e-03, fs:0.78981 (r=0.713,p=0.886),  time:3.849, tt:365.644
# Ep:95, loss:0.00003, loss_test:0.13206, lr:3.85e-03, fs:0.78481 (r=0.713,p=0.873),  time:3.848, tt:369.440
# Ep:96, loss:0.00003, loss_test:0.13684, lr:3.81e-03, fs:0.78710 (r=0.701,p=0.897),  time:3.848, tt:373.219
# Ep:97, loss:0.00003, loss_test:0.13464, lr:3.77e-03, fs:0.77215 (r=0.701,p=0.859),  time:3.847, tt:377.039
# Ep:98, loss:0.00002, loss_test:0.13267, lr:3.73e-03, fs:0.78981 (r=0.713,p=0.886),  time:3.847, tt:380.839
# Ep:99, loss:0.00003, loss_test:0.13580, lr:3.70e-03, fs:0.77707 (r=0.701,p=0.871),  time:3.846, tt:384.629
# Ep:100, loss:0.00002, loss_test:0.12825, lr:3.66e-03, fs:0.78710 (r=0.701,p=0.897),  time:3.862, tt:390.021
# Ep:101, loss:0.00002, loss_test:0.13924, lr:3.62e-03, fs:0.78205 (r=0.701,p=0.884),  time:3.861, tt:393.806
# Ep:102, loss:0.00002, loss_test:0.13100, lr:3.59e-03, fs:0.78205 (r=0.701,p=0.884),  time:3.860, tt:397.597
# Ep:103, loss:0.00002, loss_test:0.13987, lr:3.55e-03, fs:0.78205 (r=0.701,p=0.884),  time:3.859, tt:401.374
# Ep:104, loss:0.00002, loss_test:0.13604, lr:3.52e-03, fs:0.78710 (r=0.701,p=0.897),  time:3.858, tt:405.137
# Ep:105, loss:0.00002, loss_test:0.13279, lr:3.48e-03, fs:0.78710 (r=0.701,p=0.897),  time:3.858, tt:408.908
# Ep:106, loss:0.00002, loss_test:0.13865, lr:3.45e-03, fs:0.78710 (r=0.701,p=0.897),  time:3.857, tt:412.694
# Ep:107, loss:0.00002, loss_test:0.13600, lr:3.41e-03, fs:0.78481 (r=0.713,p=0.873),  time:3.856, tt:416.452
# Ep:108, loss:0.00002, loss_test:0.13632, lr:3.38e-03, fs:0.78205 (r=0.701,p=0.884),  time:3.855, tt:420.224
# Ep:109, loss:0.00002, loss_test:0.13718, lr:3.34e-03, fs:0.79221 (r=0.701,p=0.910),  time:3.855, tt:424.067
# Ep:110, loss:0.00002, loss_test:0.13301, lr:3.31e-03, fs:0.79221 (r=0.701,p=0.910),  time:3.854, tt:427.844
# Ep:111, loss:0.00002, loss_test:0.13310, lr:3.28e-03, fs:0.78710 (r=0.701,p=0.897),  time:3.854, tt:431.636
# Ep:112, loss:0.00002, loss_test:0.13180, lr:3.24e-03, fs:0.78710 (r=0.701,p=0.897),  time:3.853, tt:435.435
# Ep:113, loss:0.00002, loss_test:0.13360, lr:3.21e-03, fs:0.79221 (r=0.701,p=0.910),  time:3.853, tt:439.235
# Ep:114, loss:0.00002, loss_test:0.13710, lr:3.18e-03, fs:0.79221 (r=0.701,p=0.910),  time:3.853, tt:443.062
# Ep:115, loss:0.00002, loss_test:0.13706, lr:3.15e-03, fs:0.78710 (r=0.701,p=0.897),  time:3.852, tt:446.878
# Ep:116, loss:0.00002, loss_test:0.13452, lr:3.12e-03, fs:0.79221 (r=0.701,p=0.910),  time:3.852, tt:450.700
# Ep:117, loss:0.00002, loss_test:0.13789, lr:3.09e-03, fs:0.78710 (r=0.701,p=0.897),  time:3.853, tt:454.609
# Ep:118, loss:0.00002, loss_test:0.13795, lr:3.05e-03, fs:0.77215 (r=0.701,p=0.859),  time:3.853, tt:458.526
# Ep:119, loss:0.00001, loss_test:0.13549, lr:3.02e-03, fs:0.78710 (r=0.701,p=0.897),  time:3.854, tt:462.478
# Model and results saved
# Saving best model...
# Model and results saved

# %% [markdown]
# ## Plot results <br>
#
# <p>This will plot charts of fscore/accuracy for all the results that match the parameters options under the /results folder</p>
#
# #### Parameters options
#
# <p> Choose one of each and pass it to the corresponding plot function in the following order:
#
# <b>1) neg_sample</b> = [1,2,3,4...etc] <br>
# <b>2) ds_name</b> = ["openml_203ds_datasets_matching"] <br>
# <b>3) experiment</b> = ["10_cv","random_subsam","hold_out"] <br>
# <b>4) archi</b> = ["Fasttext_150","Fasttext_300","Bert_300","Bert_768"] <br>
# <b>5) optimizer</b> = ["adam","sgd"] <br>
# <b>6) loss_functions</b> = ["ContrastiveLoss","CosineEmbeddingLoss"] <br>
#
# #### Types of chart
# <b>plot.plot_cv_details:</b> line charts of accuracy and fscore results for the several runs in cv_10 and random_subsampling<br>
# <b>plot.plot_bar </b>: bar charts of maximum results of accuracy and fscore for the several runs in cv_10 and random_subsampling <br>
# <b>plot.plot_details</b>: line charts of accuracy, fscore, recall and precision results for a hold_out run

# %%
##examples
##Line chart: plot hold_out results
# plot.plot_details(2,"monitor","hold_out","Fasttext2_364","sgd","CosineEmbeddingLoss",nit=["50"])
##Line chart: plot 10-fold-cv and random_subsampling results
# plot.plot_bar(2,"openML","random_subsam","Fasttext2_364","sgd","CosineEmbeddingLoss",nit=["120"])
##Bar chart: plot 10-fold-cv and random_subsampling results
# plot.plot_cv_details(2,"openML","random_subsam","Fasttext2_364","sgd","CosineEmbeddingLoss",nit=["120"])

# %%
##Line chart: plot 10-fold-cv and random_subsampling results
plot.plot_bar(2,"openML","random_subsam","Fasttext2_364","sgd","CosineEmbeddingLoss",nit=["120"])

# %%
##Bar chart: plot 10-fold-cv and random_subsampling results
plot.plot_cv_details(2,"openML","random_subsam","Fasttext2_364","sgd","CosineEmbeddingLoss",nit=["120"])
